# %% [markdown]
# ## Kids Data frame

# %%
#Librairie Importation:
import os
import pandas as pd

# %%
import os
import pandas as pd

def load_and_concat_sensor_data(root_dir, i):
    concatenated_data_frames = []

    # Get the dynamic folder that matches the pattern parent
    dynamic_folder = None
    for d in os.listdir(root_dir):
        if os.path.isdir(os.path.join(root_dir, d)) and 'parent' in d:
            dynamic_folder = d
            break

    if dynamic_folder is None:
        print("No folder matching the pattern '*_parent' found.")
        return concatenated_data_frames
    else:
        # Construct the full path to the dynamic folder
        dynamic_folder_path = os.path.join(root_dir, dynamic_folder).replace("\\", "/")

        # Sensor folders to process
        sensor_folders = ['rotation', 'LinearAcceleration']

        # Construct paths to the sensor folders
        sensor_paths = {sensor: os.path.join(dynamic_folder_path, sensor).replace("\\", "/") for sensor in sensor_folders}

        # Check if sensor folders exist
        if not all(os.path.exists(sensor_path) for sensor_path in sensor_paths.values()):
            print(f"One or more sensor folders not found: {sensor_paths}")
            return concatenated_data_frames

        # Get the list of .txt files in each sensor folder (assuming they have the same number of files)
        sensor_files = {sensor: sorted([f for f in os.listdir(sensor_paths[sensor]) if f.endswith('.txt')]) for sensor in sensor_folders}

        # Iterate through the files and process them
        for rotation_file, linear_acc_file in zip(sensor_files['rotation'], sensor_files['LinearAcceleration']):
            # Construct the full file paths
            rotation_file_path = os.path.join(sensor_paths['rotation'], rotation_file).replace("\\", "/")
            linear_acc_file_path = os.path.join(sensor_paths['LinearAcceleration'], linear_acc_file).replace("\\", "/")
            
            # Read the rotation file into a DataFrame
            try:
                rotation_df = pd.read_csv(rotation_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                rotation_df.columns = ['ro_timestamp', 'ro_internal_ts', 'ro_x', 'ro_y', 'ro_z', 'ro_app_id']
                # Calculate magnitude of rotation vector
                rotation_df['ro_mag'] = (rotation_df['ro_x']**2 + rotation_df['ro_y']**2 + rotation_df['ro_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {rotation_file_path}: {e}")
                continue
            
            # Read the linear acceleration file into a DataFrame
            try:
                linear_acc_df = pd.read_csv(linear_acc_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                linear_acc_df.columns = ['la_timestamp', 'la_internal_ts', 'la_x', 'la_y', 'la_z', 'la_app_id']
                # Calculate magnitude of linear acceleration vector
                linear_acc_df['la_mag'] = (linear_acc_df['la_x']**2 + linear_acc_df['la_y']**2 + linear_acc_df['la_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {linear_acc_file_path}: {e}")
                continue

            # Concatenate the two DataFrames along columns
            concatenated_df = pd.concat([rotation_df, linear_acc_df], axis=1)
            
            # Add 'id' and 'label' columns
            concatenated_df['id'] = i+25
            concatenated_df['label'] = 0
            
            # Append the concatenated DataFrame to the list
            concatenated_data_frames.append(concatenated_df)

    return concatenated_data_frames

# Example usage to load data for Kid1 to Kid25
root_base_dir = 'D:\internship\code\KidsOnThePhone_dataset\Parents'
parents_sensors = {}

for i in range(1, 26):
    root_dir = os.path.join(root_base_dir, f'Parent{i}', 'Sensors')
    parents_sensors[f"parent{i}_sensors"] = load_and_concat_sensor_data(root_dir, i)

# Display the first concatenated DataFrame for kid1_sensors
if "parent1_sensors" in parents_sensors and parents_sensors["parent1_sensors"]:
    print(parents_sensors["parent1_sensors"][0].head(1))
# Out:
#    ro_timestamp  ro_internal_ts      ro_x      ro_y      ro_z  ro_app_id  \
# 0  1.498777e+12    5.351215e+14  0.256882  0.096115  0.324371      105.0
#
#      ro_mag   la_timestamp   la_internal_ts      la_x      la_y      la_z  \
# 0  0.424786  1498777468262  535121377667630 -0.027222  0.030685  0.206451
#
#    la_app_id    la_mag  id  label
# 0      105.0  0.210487  26      0

# %%
print(len(parents_sensors["parent1_sensors"]))
# Out:
# 18

# %% [markdown]
# ## Data Preprocessing :

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 1295
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 420
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------

# %%
for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Drop duplicates and null values inplace
        df.drop_duplicates(inplace=True)
        df.dropna(inplace=True)
        
        # Count after dropping
        num_rows_after_cleaning = len(df)
        print(f"Number of rows after cleaning: {num_rows_after_cleaning}")
        
        print("-" * 30)
    
    # No need to append, directly modify the original list in parents_sensors[key]

    print(f"Finished processing {key}")
    print("=" * 40)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1694
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1286
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 173
# ------------------------------
# Finished processing parent1_sensors
# ========================================
# Processing parent2_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1717
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1504
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 22
# ------------------------------
# Finished processing parent2_sensors
# ========================================
# Processing parent3_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1725
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1746
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1711
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1766
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1156
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1026
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 144
# ------------------------------
# Finished processing parent3_sensors
# ========================================
# Processing parent4_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 993
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 24
# ------------------------------
# Finished processing parent4_sensors
# ========================================
# Processing parent5_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing parent5_sensors
# ========================================
# Processing parent6_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1430
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 741
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 183
# ------------------------------
# Finished processing parent6_sensors
# ========================================
# Processing parent7_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1744
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 745
# ------------------------------
# Finished processing parent7_sensors
# ========================================
# Processing parent8_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1490
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 197
# ------------------------------
# Finished processing parent8_sensors
# ========================================
# Processing parent9_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1551
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 743
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 11
# ------------------------------
# Finished processing parent9_sensors
# ========================================
# Processing parent10_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 197
# ------------------------------
# Finished processing parent10_sensors
# ========================================
# Processing parent11_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 744
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 28
# ------------------------------
# Finished processing parent11_sensors
# ========================================
# Processing parent12_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1727
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1748
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 497
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 186
# ------------------------------
# Finished processing parent12_sensors
# ========================================
# Processing parent13_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing parent13_sensors
# ========================================
# Processing parent14_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 497
# ------------------------------
# Finished processing parent14_sensors
# ========================================
# Processing parent15_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 993
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 126
# ------------------------------
# Finished processing parent15_sensors
# ========================================
# Processing parent16_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1697
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 510
# ------------------------------
# Finished processing parent16_sensors
# ========================================
# Processing parent17_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 103
# ------------------------------
# Finished processing parent17_sensors
# ========================================
# Processing parent18_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 744
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 4
# ------------------------------
# Finished processing parent18_sensors
# ========================================
# Processing parent19_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 248
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 88
# ------------------------------
# Finished processing parent19_sensors
# ========================================
# Processing parent20_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 736
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 87
# ------------------------------
# Finished processing parent20_sensors
# ========================================
# Processing parent21_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 250
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 207
# ------------------------------
# Finished processing parent21_sensors
# ========================================
# Processing parent22_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1613
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1864
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1743
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1714
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1762
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1726
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1750
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1282
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 368
# ------------------------------
# Finished processing parent22_sensors
# ========================================
# Processing parent23_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1717
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1757
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1608
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1865
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1435
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 6
# ------------------------------
# Finished processing parent23_sensors
# ========================================
# Processing parent24_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 215
# ------------------------------
# Finished processing parent24_sensors
# ========================================
# Processing parent25_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1744
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 745
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 20
# ------------------------------
# Finished processing parent25_sensors
# ========================================

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------

# %%
print(parents_sensors["parent2_sensors"][2].head(30))
# Out:
#      ro_timestamp  ro_internal_ts      ro_x      ro_y      ro_z  ro_app_id  \
# 0   1499364820294  67771112321485  0.110077  0.342987  0.916183       95.0
# 1   1499364820311  67771132463087  0.110062  0.342957  0.916199       95.0
# 2   1499364820347  67771152604688  0.109955  0.342972  0.916290       95.0
# 3   1499364820364  67771172746290  0.109848  0.343033  0.916306       95.0
# 4   1499364820381  67771192887891  0.109879  0.343048  0.916275       95.0
# 5   1499364820399  67771213029493  0.109985  0.343018  0.916245       95.0
# 6   1499364820417  67771233171094  0.110001  0.343018  0.916214       95.0
# 7   1499364820434  67771253312696  0.109894  0.343033  0.916260       95.0
# 8   1499364820452  67771273454298  0.109909  0.343033  0.916260       95.0
# 9   1499364820487  67771293595899  0.109940  0.343063  0.916245       95.0
# 10  1499364820506  67771313737501  0.109863  0.343155  0.916260       95.0
# 11  1499364820522  67771333879102  0.109818  0.343155  0.916275       95.0
# 12  1499364820540  67771354020704  0.109756  0.343155  0.916290       95.0
# 13  1499364820558  67771374162305  0.109650  0.343170  0.916336       95.0
# 14  1499364820575  67771394303907  0.109650  0.343201  0.916351       95.0
# 15  1499364820593  67771414445508  0.109741  0.343201  0.916290       95.0
# 16  1499364820628  67771434587110  0.109680  0.343155  0.916321       95.0
# 17  1499364820646  67771454728712  0.109680  0.343124  0.916351       95.0
# 18  1499364820664  67771474870313  0.109665  0.343124  0.916351       95.0
# 19  1499364820681  67771495011915  0.109634  0.343140  0.916382       95.0
# 20  1499364820698  67771515153516  0.109650  0.343170  0.916367       95.0
# 21  1499364820717  67771535295118  0.109680  0.343185  0.916321       95.0
# 22  1499364820734  67771555436719  0.109695  0.343216  0.916321       95.0
# 23  1499364820770  67771575578321  0.109756  0.343246  0.916290       95.0
# 24  1499364820787  67771595719923  0.109726  0.343323  0.916321       95.0
# 25  1499364820811  67771615861524  0.109604  0.343521  0.916290       95.0
# 26  1499364820822  67771636003126  0.109375  0.343750  0.916275       95.0
# 27  1499364820840  67771656144727  0.109009  0.344040  0.916168       95.0
# 28  1499364820857  67771676286329  0.108887  0.344070  0.916138       95.0
# 29  1499364820888  67771696427930  0.108994  0.343964  0.916153       95.0
#
#       ro_mag   la_timestamp  la_internal_ts      la_x      la_y      la_z  \
# 0   0.984454  1499364820288  67771092179883  0.014343  0.104004  0.120438
# 1   0.984456  1499364820309  67771112321485  0.001511  0.058853  0.107605
# 2   0.984534  1499364820322  67771132463087  0.040543  0.090286  0.149353
# 3   0.984558  1499364820340  67771152604688 -0.087860  0.148575  0.178391
# 4   0.984538  1499364820358  67771172746290 -0.048981  0.222885  0.101791
# 5   0.984511  1499364820376  67771192887891  0.104813  0.055115  0.147583
# 6   0.984484  1499364820393  67771213029493  0.017868  0.106842 -0.041687
# 7   0.984520  1499364820429  67771233171094  0.047714  0.003891 -0.018158
# 8   0.984522  1499364820446  67771253312696 -0.007599  0.152969  0.229553
# 9   0.984522  1499364820463  67771273454298 -0.003143  0.119598  0.214767
# 10  0.984559  1499364820481  67771293595899  0.015732  0.144012  0.021042
# 11  0.984568  1499364820498  67771313737501  0.021820  0.055328 -0.015274
# 12  0.984576  1499364820516  67771333879102 -0.014084  0.080414  0.080841
# 13  0.984612  1499364820534  67771354020704  0.022049  0.074112  0.080383
# 14  0.984637  1499364820573  67771374162305 -0.082230  0.148865  0.101456
# 15  0.984590  1499364820587  67771394303907  0.004974  0.140991  0.090622
# 16  0.984596  1499364820604  67771414445508 -0.047012  0.156784  0.136551
# 17  0.984614  1499364820622  67771434587110 -0.003937  0.097061  0.230179
# 18  0.984612  1499364820640  67771454728712  0.074982  0.122223  0.100983
# 19  0.984642  1499364820657  67771474870313  0.056732  0.104034  0.046616
# 20  0.984640  1499364820675  67771495011915  0.022934  0.140472  0.017883
# 21  0.984606  1499364820710  67771515153516  0.037598  0.137024  0.063736
# 22  0.984619  1499364820728  67771535295118  0.053726  0.086121  0.054626
# 23  0.984608  1499364820745  67771555436719  0.006454  0.130295  0.143051
# 24  0.984659  1499364820763  67771575578321  0.003708  0.110352  0.092789
# 25  0.984687  1499364820780  67771595719923  0.120224  0.117126  0.044540
# 26  0.984727  1499364820811  67771615861524  0.067673  0.030991  0.131195
# 27  0.984688  1499364820817  67771636003126  0.016403  0.037125 -0.014389
# 28  0.984657  1499364820851  67771656144727 -0.059143  0.098541  0.106995
# 29  0.984646  1499364820869  67771676286329 -0.136612  0.233093  0.113876
#
#     la_app_id    la_mag  id  label
# 0        95.0  0.159774  27      0
# 1        95.0  0.122657  27      0
# 2        95.0  0.179169  27      0
# 3        95.0  0.248228  27      0
# 4        95.0  0.249877  27      0
# 5        95.0  0.189220  27      0
# 6        95.0  0.116070  27      0
# 7        95.0  0.051201  27      0
# 8        95.0  0.275957  27      0
# 9        95.0  0.245843  27      0
# 10       95.0  0.146389  27      0
# 11       95.0  0.061406  27      0
# 12       95.0  0.114891  27      0
# 13       95.0  0.111536  27      0
# 14       95.0  0.198029  27      0
# 15       95.0  0.167677  27      0
# 16       95.0  0.213161  27      0
# 17       95.0  0.249837  27      0
# 18       95.0  0.175380  27      0
# 19       95.0  0.127337  27      0
# 20       95.0  0.143451  27      0
# 21       95.0  0.155729  27      0
# 22       95.0  0.115271  27      0
# 23       95.0  0.193603  27      0
# 24       95.0  0.144225  27      0
# 25       95.0  0.173656  27      0
# 26       95.0  0.150838  27      0
# 27       95.0  0.043062  27      0
# 28       95.0  0.157023  27      0
# 29       95.0  0.293195  27      0

# %%
for key, data_frames in parents_sensors.items():
    # Initialize lists to store feature values for each DataFrame
    ids = []
    ro_x_means = []
    ro_y_means = []
    ro_z_means = []
    ro_x_maxs = []
    ro_y_maxs = []
    ro_z_maxs = []
    ro_x_mins = []
    ro_y_mins = []
    ro_z_mins = []
    ro_x_rmse = []
    ro_y_rmse = []
    ro_z_rmse = []
    ro_x_stds = []
    ro_y_stds = []
    ro_z_stds = []
    la_x_means = []
    la_y_means = []
    la_z_means = []
    la_x_maxs = []
    la_y_maxs = []
    la_z_maxs = []
    la_x_mins = []
    la_y_mins = []
    la_z_mins = []
    la_x_rmse = []
    la_y_rmse = []
    la_z_rmse = []
    la_x_stds = []
    la_y_stds = []
    la_z_stds = []
    ro_mag_means = []
    ro_mag_maxs = []
    ro_mag_mins = []
    ro_mag_rmse = []
    ro_mag_stds = []
    la_mag_means = []
    la_mag_maxs = []
    la_mag_mins = []
    la_mag_rmse = []
    la_mag_stds = []
    labels = []
    
    # Iterate through each DataFrame in the current key's list of DataFrames
    for df in data_frames:
        # Extract id and label (assuming they are the same for rotation and linear acceleration)
        ids.append(df['id'].iloc[0])
        
        # Extract features for rotation
        ro_x_means.append(df['ro_x'].mean())
        ro_y_means.append(df['ro_y'].mean())
        ro_z_means.append(df['ro_z'].mean())
        ro_x_maxs.append(df['ro_x'].max())
        ro_y_maxs.append(df['ro_y'].max())
        ro_z_maxs.append(df['ro_z'].max())
        ro_x_mins.append(df['ro_x'].min())
        ro_y_mins.append(df['ro_y'].min())
        ro_z_mins.append(df['ro_z'].min())
        ro_x_rmse.append(np.sqrt(np.mean(df['ro_x']**2)))
        ro_y_rmse.append(np.sqrt(np.mean(df['ro_y']**2)))
        ro_z_rmse.append(np.sqrt(np.mean(df['ro_z']**2)))
        ro_x_stds.append(df['ro_x'].std())
        ro_y_stds.append(df['ro_y'].std())
        ro_z_stds.append(df['ro_z'].std())

        # Compute ro_mag and extract features
        ro_mag = np.sqrt(df['ro_x']**2 + df['ro_y']**2 + df['ro_z']**2)
        ro_mag_means.append(ro_mag.mean())
        ro_mag_maxs.append(ro_mag.max())
        ro_mag_mins.append(ro_mag.min())
        ro_mag_rmse.append(np.sqrt(np.mean(ro_mag**2)))
        ro_mag_stds.append(ro_mag.std())
        
        # Extract features for linear acceleration
        la_x_means.append(df['la_x'].mean())
        la_y_means.append(df['la_y'].mean())
        la_z_means.append(df['la_z'].mean())
        la_x_maxs.append(df['la_x'].max())
        la_y_maxs.append(df['la_y'].max())
        la_z_maxs.append(df['la_z'].max())
        la_x_mins.append(df['la_x'].min())
        la_y_mins.append(df['la_y'].min())
        la_z_mins.append(df['la_z'].min())
        la_x_rmse.append(np.sqrt(np.mean(df['la_x']**2)))
        la_y_rmse.append(np.sqrt(np.mean(df['la_y']**2)))
        la_z_rmse.append(np.sqrt(np.mean(df['la_z']**2)))
        la_x_stds.append(df['la_x'].std())
        la_y_stds.append(df['la_y'].std())
        la_z_stds.append(df['la_z'].std())

        # Compute la_mag and extract features
        la_mag = np.sqrt(df['la_x']**2 + df['la_y']**2 + df['la_z']**2)
        la_mag_means.append(la_mag.mean())
        la_mag_maxs.append(la_mag.max())
        la_mag_mins.append(la_mag.min())
        la_mag_rmse.append(np.sqrt(np.mean(la_mag**2)))
        la_mag_stds.append(la_mag.std())

        # Extract label (assuming it's the same for all rows in this DataFrame)
        labels.append(df['label'].iloc[0])
    
    # Create a DataFrame for extracted features for the current key
    extracted_df = pd.DataFrame({
        'id': ids,
        'ro_x_mean': ro_x_means,
        'ro_y_mean': ro_y_means,
        'ro_z_mean': ro_z_means,
        'ro_x_max': ro_x_maxs,
        'ro_y_max': ro_y_maxs,
        'ro_z_max': ro_z_maxs,
        'ro_x_min': ro_x_mins,
        'ro_y_min': ro_y_mins,
        'ro_z_min': ro_z_mins,
        'ro_x_rmse': ro_x_rmse,
        'ro_y_rmse': ro_y_rmse,
        'ro_z_rmse': ro_z_rmse,
        'ro_x_std': ro_x_stds,
        'ro_y_std': ro_y_stds,
        'ro_z_std': ro_z_stds,
        'ro_mag_mean': ro_mag_means,
        'ro_mag_max': ro_mag_maxs,
        'ro_mag_min': ro_mag_mins,
        'ro_mag_rmse': ro_mag_rmse,
        'ro_mag_std': ro_mag_stds,
        'la_x_mean': la_x_means,
        'la_y_mean': la_y_means,
        'la_z_mean': la_z_means,
        'la_x_max': la_x_maxs,
        'la_y_max': la_y_maxs,
        'la_z_max': la_z_maxs,
        'la_x_min': la_x_mins,
        'la_y_min': la_y_mins,
        'la_z_min': la_z_mins,
        'la_x_rmse': la_x_rmse,
        'la_y_rmse': la_y_rmse,
        'la_z_rmse': la_z_rmse,
        'la_x_std': la_x_stds,
        'la_y_std': la_y_stds,
        'la_z_std': la_z_stds,
        'la_mag_mean': la_mag_means,
        'la_mag_max': la_mag_maxs,
        'la_mag_min': la_mag_mins,
        'la_mag_rmse': la_mag_rmse,
        'la_mag_std': la_mag_stds,
        'label': labels
    })
    
    # Assign the DataFrame to the corresponding key in extracted_features dictionary
    extracted_features[key] = extracted_df

# Example usage to print the first few rows of the extracted DataFrame for 'kid1_sensors'
if "parent1_sensors" in extracted_features and not extracted_features["parent1_sensors"].empty:
    print(extracted_features["parent1_sensors"].head())
# Out:
#    id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 0  26   0.205590  -0.083862   0.502972  0.314972  0.123840  0.761444
# 1  26   0.163781  -0.188551   0.593173  0.176697 -0.173920  0.602371
# 2  26   0.174730  -0.171892   0.596189  0.193970 -0.161102  0.602570
# 3  26   0.163071  -0.157918   0.600157  0.175644 -0.146378  0.604904
# 4  26   0.168763  -0.193237   0.599287  0.204163 -0.151459  0.618607
#
#    ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0  0.138000 -0.216690  0.321747  ...   0.272019  0.252229  0.212338  0.269916
# 1  0.155502 -0.198181  0.586685  ...   0.143083  0.073080  0.085827  0.142348
# 2  0.159927 -0.186386  0.587280  ...   0.174780  0.126461  0.119795  0.172402
# 3  0.153671 -0.173447  0.593552  ...   0.167808  0.081594  0.075217  0.159663
# 4  0.133133 -0.209152  0.590118  ...   0.152900  0.085408  0.116846  0.138199
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.267800    5.266115    0.008873     0.431195    0.338051      0
# 1     0.174610    1.067860    0.031145     0.207902    0.112880      0
# 2     0.200093    1.779876    0.011244     0.258935    0.164396      0
# 3     0.155247    1.392207    0.006894     0.205683    0.134961      0
# 4     0.165405    1.494733    0.014091     0.213393    0.134863      0
#
# [5 rows x 42 columns]

# %%
print(extracted_features["parent1_sensors"].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           18 non-null     int64
#  1   ro_x_mean    18 non-null     float64
#  2   ro_y_mean    18 non-null     float64
#  3   ro_z_mean    18 non-null     float64
#  4   ro_x_max     18 non-null     float64
#  5   ro_y_max     18 non-null     float64
#  6   ro_z_max     18 non-null     float64
#  7   ro_x_min     18 non-null     float64
#  8   ro_y_min     18 non-null     float64
#  9   ro_z_min     18 non-null     float64
#  10  ro_x_rmse    18 non-null     float64
#  11  ro_y_rmse    18 non-null     float64
#  12  ro_z_rmse    18 non-null     float64
#  13  ro_x_std     18 non-null     float64
#  14  ro_y_std     18 non-null     float64
#  15  ro_z_std     18 non-null     float64
#  16  ro_mag_mean  18 non-null     float64
#  17  ro_mag_max   18 non-null     float64
#  18  ro_mag_min   18 non-null     float64
#  19  ro_mag_rmse  18 non-null     float64
#  20  ro_mag_std   18 non-null     float64
#  21  la_x_mean    18 non-null     float64
#  22  la_y_mean    18 non-null     float64
#  23  la_z_mean    18 non-null     float64
#  24  la_x_max     18 non-null     float64
#  25  la_y_max     18 non-null     float64
#  26  la_z_max     18 non-null     float64
#  27  la_x_min     18 non-null     float64
#  28  la_y_min     18 non-null     float64
#  29  la_z_min     18 non-null     float64
#  30  la_x_rmse    18 non-null     float64
#  31  la_y_rmse    18 non-null     float64
#  32  la_z_rmse    18 non-null     float64
#  33  la_x_std     18 non-null     float64
#  34  la_y_std     18 non-null     float64
#  35  la_z_std     18 non-null     float64
#  36  la_mag_mean  18 non-null     float64
#  37  la_mag_max   18 non-null     float64
#  38  la_mag_min   18 non-null     float64
#  39  la_mag_rmse  18 non-null     float64
#  40  la_mag_std   18 non-null     float64
#  41  label        18 non-null     int64
# dtypes: float64(40), int64(2)
# memory usage: 6.0 KB
# None

# %%
# Concatenate all data frames into a single data frame
parents_data = pd.concat(extracted_features.values(), ignore_index=True)

# %%
print(parents_data.head(5))
print(parents_data.info())
# Out:
#    id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 0  26   0.205590  -0.083862   0.502972  0.314972  0.123840  0.761444
# 1  26   0.163781  -0.188551   0.593173  0.176697 -0.173920  0.602371
# 2  26   0.174730  -0.171892   0.596189  0.193970 -0.161102  0.602570
# 3  26   0.163071  -0.157918   0.600157  0.175644 -0.146378  0.604904
# 4  26   0.168763  -0.193237   0.599287  0.204163 -0.151459  0.618607
#
#    ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0  0.138000 -0.216690  0.321747  ...   0.272019  0.252229  0.212338  0.269916
# 1  0.155502 -0.198181  0.586685  ...   0.143083  0.073080  0.085827  0.142348
# 2  0.159927 -0.186386  0.587280  ...   0.174780  0.126461  0.119795  0.172402
# 3  0.153671 -0.173447  0.593552  ...   0.167808  0.081594  0.075217  0.159663
# 4  0.133133 -0.209152  0.590118  ...   0.152900  0.085408  0.116846  0.138199
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.267800    5.266115    0.008873     0.431195    0.338051      0
# 1     0.174610    1.067860    0.031145     0.207902    0.112880      0
# 2     0.200093    1.779876    0.011244     0.258935    0.164396      0
# 3     0.155247    1.392207    0.006894     0.205683    0.134961      0
# 4     0.165405    1.494733    0.014091     0.213393    0.134863      0
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           537 non-null    int64
#  1   ro_x_mean    537 non-null    float64
#  2   ro_y_mean    537 non-null    float64
#  3   ro_z_mean    537 non-null    float64
#  4   ro_x_max     537 non-null    float64
#  5   ro_y_max     537 non-null    float64
#  6   ro_z_max     537 non-null    float64
#  7   ro_x_min     537 non-null    float64
#  8   ro_y_min     537 non-null    float64
#  9   ro_z_min     537 non-null    float64
#  10  ro_x_rmse    537 non-null    float64
#  11  ro_y_rmse    537 non-null    float64
#  12  ro_z_rmse    537 non-null    float64
#  13  ro_x_std     537 non-null    float64
#  14  ro_y_std     537 non-null    float64
#  15  ro_z_std     537 non-null    float64
#  16  ro_mag_mean  537 non-null    float64
#  17  ro_mag_max   537 non-null    float64
#  18  ro_mag_min   537 non-null    float64
#  19  ro_mag_rmse  537 non-null    float64
#  20  ro_mag_std   537 non-null    float64
#  21  la_x_mean    537 non-null    float64
#  22  la_y_mean    537 non-null    float64
#  23  la_z_mean    537 non-null    float64
#  24  la_x_max     537 non-null    float64
#  25  la_y_max     537 non-null    float64
#  26  la_z_max     537 non-null    float64
#  27  la_x_min     537 non-null    float64
#  28  la_y_min     537 non-null    float64
#  29  la_z_min     537 non-null    float64
#  30  la_x_rmse    537 non-null    float64
#  31  la_y_rmse    537 non-null    float64
#  32  la_z_rmse    537 non-null    float64
#  33  la_x_std     537 non-null    float64
#  34  la_y_std     537 non-null    float64
#  35  la_z_std     537 non-null    float64
#  36  la_mag_mean  537 non-null    float64
#  37  la_mag_max   537 non-null    float64
#  38  la_mag_min   537 non-null    float64
#  39  la_mag_rmse  537 non-null    float64
#  40  la_mag_std   537 non-null    float64
#  41  label        537 non-null    int64
# dtypes: float64(40), int64(2)
# memory usage: 176.3 KB
# None

# %%
parents_data = parents_data.sample(frac=1, random_state=42)
print(parents_data.head())
print(parents_data.info())
# Out:
#      id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 243  37  -0.087406  -0.100299  -0.723997  0.012756  0.014877 -0.714233
# 489  48   0.217373  -0.050505  -0.154720  0.236740 -0.038193 -0.140717
# 449  46   0.093807   0.297225   0.829103  0.160873  0.436707  0.949921
# 407  45   0.107668  -0.090337   0.608525  0.125336 -0.077972  0.635208
# 105  31   0.263340  -0.345649   0.658038  0.369156 -0.272964  0.726883
#
#      ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  \
# 243 -0.167053 -0.184952 -0.734116  ...   0.442168  0.140109  0.090728
# 489  0.177994 -0.067032 -0.171722  ...   0.214333  0.102980  0.100348
# 449  0.035751  0.173920  0.758698  ...   0.243026  0.186260  0.196596
# 407  0.097412 -0.096466  0.599411  ...   0.317568  0.120684  0.147029
# 105  0.206436 -0.402512  0.599060  ...   0.729412  0.265786  0.267761
#
#      la_z_std  la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  \
# 243  0.381589     0.284684   10.872952    0.025278     0.475834    0.381387
# 489  0.164081     0.266875    0.887448    0.042072     0.291629    0.117617
# 449  0.202892     0.330626    1.623496    0.019270     0.394243    0.214803
# 407  0.240663     0.306963    2.193570    0.040391     0.373566    0.212959
# 105  0.729209     0.400111   10.652363    0.013487     0.821196    0.717336
#
#      label
# 243      0
# 489      0
# 449      0
# 407      0
# 105      0
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 243 to 46
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           537 non-null    int64
#  1   ro_x_mean    537 non-null    float64
#  2   ro_y_mean    537 non-null    float64
#  3   ro_z_mean    537 non-null    float64
#  4   ro_x_max     537 non-null    float64
#  5   ro_y_max     537 non-null    float64
#  6   ro_z_max     537 non-null    float64
#  7   ro_x_min     537 non-null    float64
#  8   ro_y_min     537 non-null    float64
#  9   ro_z_min     537 non-null    float64
#  10  ro_x_rmse    537 non-null    float64
#  11  ro_y_rmse    537 non-null    float64
#  12  ro_z_rmse    537 non-null    float64
#  13  ro_x_std     537 non-null    float64
#  14  ro_y_std     537 non-null    float64
#  15  ro_z_std     537 non-null    float64
#  16  ro_mag_mean  537 non-null    float64
#  17  ro_mag_max   537 non-null    float64
#  18  ro_mag_min   537 non-null    float64
#  19  ro_mag_rmse  537 non-null    float64
#  20  ro_mag_std   537 non-null    float64
#  21  la_x_mean    537 non-null    float64
#  22  la_y_mean    537 non-null    float64
#  23  la_z_mean    537 non-null    float64
#  24  la_x_max     537 non-null    float64
#  25  la_y_max     537 non-null    float64
#  26  la_z_max     537 non-null    float64
#  27  la_x_min     537 non-null    float64
#  28  la_y_min     537 non-null    float64
#  29  la_z_min     537 non-null    float64
#  30  la_x_rmse    537 non-null    float64
#  31  la_y_rmse    537 non-null    float64
#  32  la_z_rmse    537 non-null    float64
#  33  la_x_std     537 non-null    float64
#  34  la_y_std     537 non-null    float64
#  35  la_z_std     537 non-null    float64
#  36  la_mag_mean  537 non-null    float64
#  37  la_mag_max   537 non-null    float64
#  38  la_mag_min   537 non-null    float64
#  39  la_mag_rmse  537 non-null    float64
#  40  la_mag_std   537 non-null    float64
#  41  label        537 non-null    int64
# dtypes: float64(40), int64(2)
# memory usage: 180.4 KB
# None

# %%
# Define the output file path
output_file = 'parents.csv'

# Save the concatenated DataFrame to a CSV file
parents_data.to_csv(output_file, index=False)

print(f"Concatenated features saved to {output_file}")
# Out:
# Concatenated features saved to parents.csv

# %% [markdown]
# Concat the two csv to have the whole data set :

# %%
import pandas as pd

# Load the CSV files
parents_df = pd.read_csv('parents.csv')
kids_df = pd.read_csv('kids.csv')

# Concatenate the DataFrames
data= pd.concat([parents_df, kids_df], ignore_index=True)

# Shuffle the combined DataFrame
data = data.sample(frac=1, random_state=42)


# Save the shuffled DataFrame to a new CSV file
data.to_csv('data.csv', index=False)

# %%
print(data.head(5))
# Out:
#       id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 319   40   0.038443  -0.107738  -0.495036  0.085754 -0.047119 -0.039917
# 956   19  -0.058543   0.182942   0.811790  0.128311  0.238663  0.977158
# 1094  20   0.028148   0.019518  -0.103616  0.153564  0.359055  0.982727
# 86    37   0.166467   0.305184   0.749486  0.179657  0.310333  0.754242
# 990   22   0.175506   0.003455  -0.028937  0.400620  0.071609  0.208176
#
#       ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  \
# 319  -0.142303 -0.308090 -0.623459  ...   0.296502  0.268850  0.131000
# 956  -0.120255 -0.208908 -0.974197  ...   0.355238  0.246884  0.221454
# 1094 -0.021713 -0.198868 -0.987534  ...   0.496602  0.377996  0.656716
# 86    0.156876  0.299896  0.746658  ...   0.159691  0.053282  0.045621
# 990   0.053802 -0.128281 -0.156189  ...   0.339760  0.203997  0.167537
#
#       la_z_std  la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  \
# 319   0.285267     0.202089    5.458757    0.008285     0.421151    0.369603
# 956   0.347310     0.530118    6.511254    0.110745     0.628895    0.338451
# 1094  0.436862     0.608166    3.784070    0.049939     0.906965    0.674133
# 86    0.077581     0.195518    0.460002    0.029947     0.205369    0.062862
# 990   0.262096     0.337743    3.462111    0.037485     0.434074    0.272750
#
#       label
# 319       0
# 956       1
# 1094      1
# 86        0
# 990       1
#
# [5 rows x 42 columns]
