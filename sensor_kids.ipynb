# %% [markdown]
# ## Kids Data frame

# %%
#Librairie Importation:
import os
import pandas as pd

# %%
import os
import pandas as pd

def load_and_concat_sensor_data(root_dir, i):
    concatenated_data_frames = []

    # Get the dynamic folder that matches the pattern *_kid
    dynamic_folder = None
    for d in os.listdir(root_dir):
        if os.path.isdir(os.path.join(root_dir, d)) and '_kid' in d:
            dynamic_folder = d
            break

    if dynamic_folder is None:
        print("No folder matching the pattern '*_kid' found.")
        return concatenated_data_frames
    else:
        # Construct the full path to the dynamic folder
        dynamic_folder_path = os.path.join(root_dir, dynamic_folder).replace("\\", "/")

        # Sensor folders to process
        sensor_folders = ['rotation', 'LinearAcceleration']

        # Construct paths to the sensor folders
        sensor_paths = {sensor: os.path.join(dynamic_folder_path, sensor).replace("\\", "/") for sensor in sensor_folders}

        # Check if sensor folders exist
        if not all(os.path.exists(sensor_path) for sensor_path in sensor_paths.values()):
            print(f"One or more sensor folders not found: {sensor_paths}")
            return concatenated_data_frames

        # Get the list of .txt files in each sensor folder (assuming they have the same number of files)
        sensor_files = {sensor: sorted([f for f in os.listdir(sensor_paths[sensor]) if f.endswith('.txt')]) for sensor in sensor_folders}

        # Iterate through the files and process them
        for rotation_file, linear_acc_file in zip(sensor_files['rotation'], sensor_files['LinearAcceleration']):
            # Construct the full file paths
            rotation_file_path = os.path.join(sensor_paths['rotation'], rotation_file).replace("\\", "/")
            linear_acc_file_path = os.path.join(sensor_paths['LinearAcceleration'], linear_acc_file).replace("\\", "/")
            
            # Read the rotation file into a DataFrame
            try:
                rotation_df = pd.read_csv(rotation_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                rotation_df.columns = ['ro_timestamp', 'ro_internal_ts', 'ro_x', 'ro_y', 'ro_z', 'ro_app_id']
                # Calculate magnitude of rotation vector
                rotation_df['ro_mag'] = (rotation_df['ro_x']**2 + rotation_df['ro_y']**2 + rotation_df['ro_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {rotation_file_path}: {e}")
                continue
            
            # Read the linear acceleration file into a DataFrame
            try:
                linear_acc_df = pd.read_csv(linear_acc_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                linear_acc_df.columns = ['la_timestamp', 'la_internal_ts', 'la_x', 'la_y', 'la_z', 'la_app_id']
                # Calculate magnitude of linear acceleration vector
                linear_acc_df['la_mag'] = (linear_acc_df['la_x']**2 + linear_acc_df['la_y']**2 + linear_acc_df['la_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {linear_acc_file_path}: {e}")
                continue

            # Concatenate the two DataFrames along columns
            concatenated_df = pd.concat([rotation_df, linear_acc_df], axis=1)
            
            # Add 'id' and 'label' columns
            concatenated_df['id'] = i
            concatenated_df['label'] = 1
            
            # Append the concatenated DataFrame to the list
            concatenated_data_frames.append(concatenated_df)

    return concatenated_data_frames

# Example usage to load data for Kid1 to Kid25
root_base_dir = 'D:/internship/code/KidsOnThePhone_dataset/Kids'
kids_sensors = {}

for i in range(1, 26):
    root_dir = os.path.join(root_base_dir, f'Kid{i}', 'Sensors')
    kids_sensors[f"kid{i}_sensors"] = load_and_concat_sensor_data(root_dir, i)

# Display the first concatenated DataFrame for kid1_sensors
if "kid1_sensors" in kids_sensors and kids_sensors["kid1_sensors"]:
    print(kids_sensors["kid1_sensors"][0].head(1))
# Out:
#    ro_timestamp  ro_internal_ts      ro_x      ro_y      ro_z  ro_app_id  \
# 0  1.498776e+12    5.338069e+14  0.309998  0.073929  0.143112      105.0
#
#      ro_mag   la_timestamp   la_internal_ts      la_x      la_y      la_z  \
# 0  0.349349  1498776153671  533806775477233  0.177094 -0.224823 -0.130081
#
#    la_app_id   la_mag  id  label
# 0      105.0  0.31437   1      1

# %%
print(len(kids_sensors["kid1_sensors"]))
# Out:
# 23

# %% [markdown]
# ## Data Preprocessing :

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in kids_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing kid1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 36
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 36
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 37:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 38:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 39:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 40:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 41:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# Processing kid16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# Processing kid20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 30
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# Processing kid22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 24
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 12
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 37:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------
# DataFrame 38:
# Number of duplicates: 0
# Number of null values: 6
# ------------------------------

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in kids_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Drop duplicates and null values inplace
        df.drop_duplicates(inplace=True)
        df.dropna(inplace=True)
        
        # Count after dropping
        num_rows_after_cleaning = len(df)
        print(f"Number of rows after cleaning: {num_rows_after_cleaning}")
        
        print("-" * 30)
    
    # No need to append, directly modify the original list in kids_sensors[key]

    print(f"Finished processing {key}")
    print("=" * 40)
# Out:
# Processing kid1_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1729
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1744
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1742
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1702
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1741
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 529
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 172
# ------------------------------
# Finished processing kid1_sensors
# ========================================
# Processing kid2_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1743
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1517
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1961
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1202
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 271
# ------------------------------
# Finished processing kid2_sensors
# ========================================
# Processing kid3_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1668
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1808
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1729
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1644
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1696
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1769
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1853
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1669
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1809
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1581
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1898
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 735
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 54
# ------------------------------
# Finished processing kid3_sensors
# ========================================
# Processing kid4_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1540
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1929
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1622
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1842
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1758
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1606
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1881
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1661
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1815
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1741
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1279
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 2201
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1608
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 269
# ------------------------------
# Finished processing kid4_sensors
# ========================================
# Processing kid5_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1236
# ------------------------------
# Finished processing kid5_sensors
# ========================================
# Processing kid6_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing kid6_sensors
# ========================================
# Processing kid7_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1714
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1444
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 2061
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1209
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 999
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 2827
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1550
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 2094
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1710
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1783
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1742
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1641
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1837
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1693
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1785
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1724
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1752
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1554
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 768
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 356
# ------------------------------
# Finished processing kid7_sensors
# ========================================
# Processing kid8_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1490
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 93
# ------------------------------
# Finished processing kid8_sensors
# ========================================
# Processing kid9_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 34:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 35:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 36:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 37:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 38:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 39:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 40:
# Number of rows after cleaning: 995
# ------------------------------
# DataFrame 41:
# Number of rows after cleaning: 19
# ------------------------------
# Finished processing kid9_sensors
# ========================================
# Processing kid10_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 119
# ------------------------------
# Finished processing kid10_sensors
# ========================================
# Processing kid11_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 993
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 20
# ------------------------------
# Finished processing kid11_sensors
# ========================================
# Processing kid12_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1746
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 496
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 21
# ------------------------------
# Finished processing kid12_sensors
# ========================================
# Processing kid13_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1733
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1743
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 496
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 101
# ------------------------------
# Finished processing kid13_sensors
# ========================================
# Processing kid14_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1743
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing kid14_sensors
# ========================================
# Processing kid15_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 744
# ------------------------------
# Finished processing kid15_sensors
# ========================================
# Processing kid16_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1741
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1489
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 160
# ------------------------------
# Finished processing kid16_sensors
# ========================================
# Processing kid17_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1741
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 248
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 170
# ------------------------------
# Finished processing kid17_sensors
# ========================================
# Processing kid18_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 745
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 175
# ------------------------------
# Finished processing kid18_sensors
# ========================================
# Processing kid19_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 497
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 160
# ------------------------------
# Finished processing kid19_sensors
# ========================================
# Processing kid20_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1703
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1773
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1651
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 501
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 262
# ------------------------------
# Finished processing kid20_sensors
# ========================================
# Processing kid21_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1722
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1753
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 34:
# Number of rows after cleaning: 217
# ------------------------------
# Finished processing kid21_sensors
# ========================================
# Processing kid22_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 34:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 35:
# Number of rows after cleaning: 497
# ------------------------------
# DataFrame 36:
# Number of rows after cleaning: 205
# ------------------------------
# Finished processing kid22_sensors
# ========================================
# Processing kid23_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 34:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 35:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 36:
# Number of rows after cleaning: 248
# ------------------------------
# Finished processing kid23_sensors
# ========================================
# Processing kid24_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1693
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1783
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 248
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 200
# ------------------------------
# Finished processing kid24_sensors
# ========================================
# Processing kid25_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1729
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1746
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 34:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 35:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 36:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 37:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 38:
# Number of rows after cleaning: 186
# ------------------------------
# Finished processing kid25_sensors
# ========================================

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in kids_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing kid1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 37:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 38:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 39:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 40:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 41:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing kid25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 34:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 35:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 36:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 37:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 38:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------

# %%
print(kids_sensors["kid2_sensors"][2].head(30))
# Out:
#      ro_timestamp   ro_internal_ts      ro_x      ro_y      ro_z  ro_app_id  \
# 0   1499123805646  881458752269552  0.375717  0.587265  0.647903       99.0
# 1   1499123805666  881458772411154  0.376541  0.587738  0.647156       99.0
# 2   1499123805683  881458792552756  0.377228  0.587830  0.646469       99.0
# 3   1499123805701  881458812694357  0.377594  0.587753  0.646164       99.0
# 4   1499123805723  881458832835959  0.377777  0.587814  0.646332       99.0
# 5   1499123805737  881458852977560  0.378006  0.587860  0.647079       99.0
# 6   1499123805771  881458873119162  0.378433  0.587570  0.648209       99.0
# 7   1499123805790  881458893260763  0.378555  0.587189  0.649628       99.0
# 8   1499123805807  881458913402365  0.378799  0.586426  0.650970       99.0
# 9   1499123805824  881458933543967  0.378830  0.585724  0.652222       99.0
# 10  1499123805843  881458953685568  0.378967  0.584641  0.653564       99.0
# 11  1499123805861  881458973827170  0.379135  0.582947  0.655365       99.0
# 12  1499123805879  881458993968771  0.378983  0.580887  0.657791       99.0
# 13  1499123805896  881459014110373  0.378387  0.578674  0.660858       99.0
# 14  1499123805939  881459034251974  0.377365  0.576614  0.664322       99.0
# 15  1499123805950  881459054393576  0.375610  0.574783  0.668213       99.0
# 16  1499123805971  881459074535177  0.373199  0.573029  0.672455       99.0
# 17  1499123805986  881459094676779  0.370468  0.571060  0.677048       99.0
# 18  1499123806004  881459114818381  0.367035  0.568924  0.682312       99.0
# 19  1499123806021  881459134959982  0.362701  0.566498  0.688583       99.0
# 20  1499123806039  881459155101584  0.357910  0.563095  0.695984       99.0
# 21  1499123806076  881459175243185  0.352615  0.558762  0.704346       99.0
# 22  1499123806093  881459195384787  0.347336  0.553848  0.713089       99.0
# 23  1499123806111  881459215526388  0.342041  0.548950  0.721771       99.0
# 24  1499123806130  881459235667990  0.336761  0.544571  0.729874       99.0
# 25  1499123806147  881459255809592  0.331635  0.540909  0.737122       99.0
# 26  1499123806165  881459275951193  0.326736  0.537796  0.743744       99.0
# 27  1499123806182  881459296092795  0.321808  0.534409  0.750443       99.0
# 28  1499123806200  881459316234396  0.315872  0.530487  0.757965       99.0
# 29  1499123806237  881459336375998  0.308594  0.525787  0.766541       99.0
#
#       ro_mag   la_timestamp   la_internal_ts      la_x      la_y      la_z  \
# 0   0.951747  1499123805640  881458752269552 -0.540146 -0.122040  0.168091
# 1   0.951856  1499123805662  881458772411154 -0.641663 -0.173508  0.282364
# 2   0.951718  1499123805693  881458792552756 -0.545120 -0.350952  0.220917
# 3   0.951609  1499123805721  881458812694357 -0.670120 -0.521240  0.107971
# 4   0.951833  1499123805731  881458832835959 -0.570374 -0.489334  0.116074
# 5   0.952460  1499123805747  881458852977560 -0.634506 -0.498856  0.086319
# 6   0.953218  1499123805765  881458873119162 -0.709106 -0.284592  0.098404
# 7   0.953997  1499123805785  881458893260763 -0.704956 -0.103455  0.082596
# 8   0.954540  1499123805800  881458913402365 -0.680923 -0.052963  0.253174
# 9   0.954975  1499123805819  881458933543967 -0.531174 -0.120911  0.122986
# 10  0.955284  1499123805854  881458953685568 -0.395264 -0.032013  0.279175
# 11  0.955549  1499123805874  881458973827170 -0.364853 -0.120010  0.380844
# 12  0.955901  1499123805892  881458993968771 -0.177383 -0.103180  0.382126
# 13  0.956438  1499123805907  881459014110373 -0.011581 -0.052292  0.325943
# 14  0.957190  1499123805925  881459034251974 -0.061707  0.012680  0.333206
# 15  0.958106  1499123805943  881459054393576 -0.110718  0.057343  0.299805
# 16  0.959080  1499123805961  881459074535177 -0.260651 -0.019135  0.217209
# 17  0.960078  1499123805979  881459094676779 -0.295120 -0.214188  0.175797
# 18  0.961217  1499123806014  881459114818381 -0.571350 -0.289169  0.139542
# 19  0.962611  1499123806032  881459134959982 -0.826828 -0.533203  0.296158
# 20  0.964142  1499123806051  881459155101584 -0.899567 -0.649292  0.436249
# 21  0.965741  1499123806068  881459175243185 -0.904663 -0.723923  0.405746
# 22  0.967412  1499123806087  881459195384787 -0.909134 -0.684906  0.372147
# 23  0.969171  1499123806107  881459215526388 -0.876968 -0.526917  0.308563
# 24  0.970918  1499123806124  881459235667990 -0.819641 -0.393951  0.462402
# 25  0.972580  1499123806160  881459255809592 -0.719452 -0.303558  0.183182
# 26  0.974236  1499123806175  881459275951193 -0.329300 -0.213379  0.261200
# 27  0.975867  1499123806194  881459296092795 -0.142365 -0.247589  0.426331
# 28  0.977601  1499123806215  881459316234396 -0.085403 -0.108932  0.558167
# 29  0.979422  1499123806229  881459336375998 -0.097443 -0.121201  0.577225
#
#     la_app_id    la_mag  id  label
# 0        99.0  0.578710   2      1
# 1        99.0  0.722195   2      1
# 2        99.0  0.684929   2      1
# 3        99.0  0.855810   2      1
# 4        99.0  0.760425   2      1
# 5        99.0  0.811730   2      1
# 6        99.0  0.770395   2      1
# 7        99.0  0.717278   2      1
# 8        99.0  0.728395   2      1
# 9        99.0  0.558471   2      1
# 10       99.0  0.484971   2      1
# 11       99.0  0.540890   2      1
# 12       99.0  0.433741   2      1
# 13       99.0  0.330314   2      1
# 14       99.0  0.339109   2      1
# 15       99.0  0.324699   2      1
# 16       99.0  0.339830   2      1
# 17       99.0  0.404817   2      1
# 18       99.0  0.655387   2      1
# 19       99.0  1.027453   2      1
# 20       99.0  1.192105   2      1
# 21       99.0  1.227644   2      1
# 22       99.0  1.197545   2      1
# 23       99.0  1.068609   2      1
# 24       99.0  1.020208   2      1
# 25       99.0  0.802069   2      1
# 26       99.0  0.471375   2      1
# 27       99.0  0.513153   2      1
# 28       99.0  0.575074   2      1
# 29       99.0  0.597807   2      1

# %%
import numpy as np
import pandas as pd

# Initialize the dictionary to store extracted features
extracted_features = {}

# Iterate through each key (e.g., 'kid1_sensors', 'kid2_sensors', etc.) in kids_sensors
for key, data_frames in kids_sensors.items():
    # Initialize lists to store feature values for each DataFrame
    ids = []
    ro_x_means = []
    ro_y_means = []
    ro_z_means = []
    ro_x_maxs = []
    ro_y_maxs = []
    ro_z_maxs = []
    ro_x_mins = []
    ro_y_mins = []
    ro_z_mins = []
    ro_x_rmse = []
    ro_y_rmse = []
    ro_z_rmse = []
    ro_x_stds = []
    ro_y_stds = []
    ro_z_stds = []
    la_x_means = []
    la_y_means = []
    la_z_means = []
    la_x_maxs = []
    la_y_maxs = []
    la_z_maxs = []
    la_x_mins = []
    la_y_mins = []
    la_z_mins = []
    la_x_rmse = []
    la_y_rmse = []
    la_z_rmse = []
    la_x_stds = []
    la_y_stds = []
    la_z_stds = []
    ro_mag_means = []
    ro_mag_maxs = []
    ro_mag_mins = []
    ro_mag_rmse = []
    ro_mag_stds = []
    la_mag_means = []
    la_mag_maxs = []
    la_mag_mins = []
    la_mag_rmse = []
    la_mag_stds = []
    labels = []
    
    # Iterate through each DataFrame in the current key's list of DataFrames
    for df in data_frames:
        # Extract id and label (assuming they are the same for rotation and linear acceleration)
        ids.append(df['id'].iloc[0])
        
        # Extract features for rotation
        ro_x_means.append(df['ro_x'].mean())
        ro_y_means.append(df['ro_y'].mean())
        ro_z_means.append(df['ro_z'].mean())
        ro_x_maxs.append(df['ro_x'].max())
        ro_y_maxs.append(df['ro_y'].max())
        ro_z_maxs.append(df['ro_z'].max())
        ro_x_mins.append(df['ro_x'].min())
        ro_y_mins.append(df['ro_y'].min())
        ro_z_mins.append(df['ro_z'].min())
        ro_x_rmse.append(np.sqrt(np.mean(df['ro_x']**2)))
        ro_y_rmse.append(np.sqrt(np.mean(df['ro_y']**2)))
        ro_z_rmse.append(np.sqrt(np.mean(df['ro_z']**2)))
        ro_x_stds.append(df['ro_x'].std())
        ro_y_stds.append(df['ro_y'].std())
        ro_z_stds.append(df['ro_z'].std())

        # Compute ro_mag and extract features
        ro_mag = np.sqrt(df['ro_x']**2 + df['ro_y']**2 + df['ro_z']**2)
        ro_mag_means.append(ro_mag.mean())
        ro_mag_maxs.append(ro_mag.max())
        ro_mag_mins.append(ro_mag.min())
        ro_mag_rmse.append(np.sqrt(np.mean(ro_mag**2)))
        ro_mag_stds.append(ro_mag.std())
        
        # Extract features for linear acceleration
        la_x_means.append(df['la_x'].mean())
        la_y_means.append(df['la_y'].mean())
        la_z_means.append(df['la_z'].mean())
        la_x_maxs.append(df['la_x'].max())
        la_y_maxs.append(df['la_y'].max())
        la_z_maxs.append(df['la_z'].max())
        la_x_mins.append(df['la_x'].min())
        la_y_mins.append(df['la_y'].min())
        la_z_mins.append(df['la_z'].min())
        la_x_rmse.append(np.sqrt(np.mean(df['la_x']**2)))
        la_y_rmse.append(np.sqrt(np.mean(df['la_y']**2)))
        la_z_rmse.append(np.sqrt(np.mean(df['la_z']**2)))
        la_x_stds.append(df['la_x'].std())
        la_y_stds.append(df['la_y'].std())
        la_z_stds.append(df['la_z'].std())

        # Compute la_mag and extract features
        la_mag = np.sqrt(df['la_x']**2 + df['la_y']**2 + df['la_z']**2)
        la_mag_means.append(la_mag.mean())
        la_mag_maxs.append(la_mag.max())
        la_mag_mins.append(la_mag.min())
        la_mag_rmse.append(np.sqrt(np.mean(la_mag**2)))
        la_mag_stds.append(la_mag.std())

        # Extract label (assuming it's the same for all rows in this DataFrame)
        labels.append(df['label'].iloc[0])
    
    # Create a DataFrame for extracted features for the current key
    extracted_df = pd.DataFrame({
        'id': ids,
        'ro_x_mean': ro_x_means,
        'ro_y_mean': ro_y_means,
        'ro_z_mean': ro_z_means,
        'ro_x_max': ro_x_maxs,
        'ro_y_max': ro_y_maxs,
        'ro_z_max': ro_z_maxs,
        'ro_x_min': ro_x_mins,
        'ro_y_min': ro_y_mins,
        'ro_z_min': ro_z_mins,
        'ro_x_rmse': ro_x_rmse,
        'ro_y_rmse': ro_y_rmse,
        'ro_z_rmse': ro_z_rmse,
        'ro_x_std': ro_x_stds,
        'ro_y_std': ro_y_stds,
        'ro_z_std': ro_z_stds,
        'ro_mag_mean': ro_mag_means,
        'ro_mag_max': ro_mag_maxs,
        'ro_mag_min': ro_mag_mins,
        'ro_mag_rmse': ro_mag_rmse,
        'ro_mag_std': ro_mag_stds,
        'la_x_mean': la_x_means,
        'la_y_mean': la_y_means,
        'la_z_mean': la_z_means,
        'la_x_max': la_x_maxs,
        'la_y_max': la_y_maxs,
        'la_z_max': la_z_maxs,
        'la_x_min': la_x_mins,
        'la_y_min': la_y_mins,
        'la_z_min': la_z_mins,
        'la_x_rmse': la_x_rmse,
        'la_y_rmse': la_y_rmse,
        'la_z_rmse': la_z_rmse,
        'la_x_std': la_x_stds,
        'la_y_std': la_y_stds,
        'la_z_std': la_z_stds,
        'la_mag_mean': la_mag_means,
        'la_mag_max': la_mag_maxs,
        'la_mag_min': la_mag_mins,
        'la_mag_rmse': la_mag_rmse,
        'la_mag_std': la_mag_stds,
        'label': labels
    })
    
    # Assign the DataFrame to the corresponding key in extracted_features dictionary
    extracted_features[key] = extracted_df

# Example usage to print the first few rows of the extracted DataFrame for 'kid1_sensors'
if "kid1_sensors" in extracted_features and not extracted_features["kid1_sensors"].empty:
    print(extracted_features["kid1_sensors"].head())
# Out:
#    id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 0   1   0.211515  -0.089528   0.003718  0.334061  0.109970  0.345322
# 1   1   0.064150  -0.334205   0.141335  0.112015 -0.273285  0.183792
# 2   1   0.047013  -0.372772   0.121156  0.111160 -0.322327  0.254898
# 3   1   0.055543  -0.348347   0.147268  0.152435 -0.277802  0.205978
# 4   1   0.078702  -0.352490   0.169944  0.139175 -0.284180  0.275711
#
#    ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0  0.057495 -0.322662 -0.204834  ...   0.371293  0.366098  0.304171  0.371249
# 1  0.024780 -0.422302  0.086090  ...   0.361042  0.196294  0.133895  0.357994
# 2 -0.023392 -0.461151  0.069412  ...   0.368192  0.210187  0.225796  0.365996
# 3 -0.016815 -0.445572 -0.002411  ...   0.396734  0.212522  0.179589  0.393421
# 4 -0.005203 -0.404251  0.107437  ...   0.251352  0.233390  0.208717  0.244713
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.417157    4.000196    0.016519     0.603706    0.436521      1
# 1     0.265373    6.893459    0.008973     0.434315    0.343910      1
# 2     0.336326    3.978197    0.011672     0.484145    0.348355      1
# 3     0.350869    4.121691    0.017404     0.489415    0.341299      1
# 4     0.301386    4.386225    0.023561     0.408257    0.275471      1
#
# [5 rows x 42 columns]

# %%
print(extracted_features["kid1_sensors"].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           23 non-null     int64
#  1   ro_x_mean    23 non-null     float64
#  2   ro_y_mean    23 non-null     float64
#  3   ro_z_mean    23 non-null     float64
#  4   ro_x_max     23 non-null     float64
#  5   ro_y_max     23 non-null     float64
#  6   ro_z_max     23 non-null     float64
#  7   ro_x_min     23 non-null     float64
#  8   ro_y_min     23 non-null     float64
#  9   ro_z_min     23 non-null     float64
#  10  ro_x_rmse    23 non-null     float64
#  11  ro_y_rmse    23 non-null     float64
#  12  ro_z_rmse    23 non-null     float64
#  13  ro_x_std     23 non-null     float64
#  14  ro_y_std     23 non-null     float64
#  15  ro_z_std     23 non-null     float64
#  16  ro_mag_mean  23 non-null     float64
#  17  ro_mag_max   23 non-null     float64
#  18  ro_mag_min   23 non-null     float64
#  19  ro_mag_rmse  23 non-null     float64
#  20  ro_mag_std   23 non-null     float64
#  21  la_x_mean    23 non-null     float64
#  22  la_y_mean    23 non-null     float64
#  23  la_z_mean    23 non-null     float64
#  24  la_x_max     23 non-null     float64
#  25  la_y_max     23 non-null     float64
#  26  la_z_max     23 non-null     float64
#  27  la_x_min     23 non-null     float64
#  28  la_y_min     23 non-null     float64
#  29  la_z_min     23 non-null     float64
#  30  la_x_rmse    23 non-null     float64
#  31  la_y_rmse    23 non-null     float64
#  32  la_z_rmse    23 non-null     float64
#  33  la_x_std     23 non-null     float64
#  34  la_y_std     23 non-null     float64
#  35  la_z_std     23 non-null     float64
#  36  la_mag_mean  23 non-null     float64
#  37  la_mag_max   23 non-null     float64
#  38  la_mag_min   23 non-null     float64
#  39  la_mag_rmse  23 non-null     float64
#  40  la_mag_std   23 non-null     float64
#  41  label        23 non-null     int64
# dtypes: float64(40), int64(2)
# memory usage: 7.7 KB
# None

# %%
# Concatenate all data frames into a single data frame
kids_data = pd.concat(extracted_features.values(), ignore_index=True)

# %%
print(kids_data.head(5))
print(kids_data.info())
# Out:
#    id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 0   1   0.211515  -0.089528   0.003718  0.334061  0.109970  0.345322
# 1   1   0.064150  -0.334205   0.141335  0.112015 -0.273285  0.183792
# 2   1   0.047013  -0.372772   0.121156  0.111160 -0.322327  0.254898
# 3   1   0.055543  -0.348347   0.147268  0.152435 -0.277802  0.205978
# 4   1   0.078702  -0.352490   0.169944  0.139175 -0.284180  0.275711
#
#    ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0  0.057495 -0.322662 -0.204834  ...   0.371293  0.366098  0.304171  0.371249
# 1  0.024780 -0.422302  0.086090  ...   0.361042  0.196294  0.133895  0.357994
# 2 -0.023392 -0.461151  0.069412  ...   0.368192  0.210187  0.225796  0.365996
# 3 -0.016815 -0.445572 -0.002411  ...   0.396734  0.212522  0.179589  0.393421
# 4 -0.005203 -0.404251  0.107437  ...   0.251352  0.233390  0.208717  0.244713
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.417157    4.000196    0.016519     0.603706    0.436521      1
# 1     0.265373    6.893459    0.008973     0.434315    0.343910      1
# 2     0.336326    3.978197    0.011672     0.484145    0.348355      1
# 3     0.350869    4.121691    0.017404     0.489415    0.341299      1
# 4     0.301386    4.386225    0.023561     0.408257    0.275471      1
#
# [5 rows x 42 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           647 non-null    int64
#  1   ro_x_mean    647 non-null    float64
#  2   ro_y_mean    647 non-null    float64
#  3   ro_z_mean    647 non-null    float64
#  4   ro_x_max     647 non-null    float64
#  5   ro_y_max     647 non-null    float64
#  6   ro_z_max     647 non-null    float64
#  7   ro_x_min     647 non-null    float64
#  8   ro_y_min     647 non-null    float64
#  9   ro_z_min     647 non-null    float64
#  10  ro_x_rmse    647 non-null    float64
#  11  ro_y_rmse    647 non-null    float64
#  12  ro_z_rmse    647 non-null    float64
#  13  ro_x_std     647 non-null    float64
#  14  ro_y_std     647 non-null    float64
#  15  ro_z_std     647 non-null    float64
#  16  ro_mag_mean  647 non-null    float64
#  17  ro_mag_max   647 non-null    float64
#  18  ro_mag_min   647 non-null    float64
#  19  ro_mag_rmse  647 non-null    float64
#  20  ro_mag_std   647 non-null    float64
#  21  la_x_mean    647 non-null    float64
#  22  la_y_mean    647 non-null    float64
#  23  la_z_mean    647 non-null    float64
#  24  la_x_max     647 non-null    float64
#  25  la_y_max     647 non-null    float64
#  26  la_z_max     647 non-null    float64
#  27  la_x_min     647 non-null    float64
#  28  la_y_min     647 non-null    float64
#  29  la_z_min     647 non-null    float64
#  30  la_x_rmse    647 non-null    float64
#  31  la_y_rmse    647 non-null    float64
#  32  la_z_rmse    647 non-null    float64
#  33  la_x_std     647 non-null    float64
#  34  la_y_std     647 non-null    float64
#  35  la_z_std     647 non-null    float64
#  36  la_mag_mean  647 non-null    float64
#  37  la_mag_max   647 non-null    float64
#  38  la_mag_min   647 non-null    float64
#  39  la_mag_rmse  647 non-null    float64
#  40  la_mag_std   647 non-null    float64
#  41  label        647 non-null    int64
# dtypes: float64(40), int64(2)
# memory usage: 212.4 KB
# None

# %%
kids_data = kids_data.sample(frac=1, random_state=42)
print(kids_data.head())
# Out:
#      id  ro_x_mean  ro_y_mean  ro_z_mean  ro_x_max  ro_y_max  ro_z_max  \
# 634  25   0.391358  -0.024481   0.177286  0.418823  0.002319  0.192184
# 220  11   0.082882  -0.127687   0.465300  0.110275 -0.091537  0.493652
# 426  19   0.048871   0.212403   0.723906  0.116348  0.249390  0.836884
# 428  19   0.217404   0.065850  -0.078850  0.247879  0.112488  0.143860
# 72    4  -0.065928  -0.299645  -0.331634 -0.000870 -0.176041 -0.181244
#
#      ro_x_min  ro_y_min  ro_z_min  ...  la_z_rmse  la_x_std  la_y_std  \
# 634  0.361465 -0.042343  0.167801  ...   0.146353  0.051768  0.048705
# 220  0.026962 -0.282455  0.394089  ...   0.505619  0.246158  0.235012
# 426 -0.016693  0.170715  0.583511  ...   0.539683  0.214234  0.244968
# 428  0.192719 -0.012497 -0.299057  ...   0.268936  0.178997  0.176665
# 72  -0.230560 -0.432114 -0.478546  ...   0.954466  0.447212  0.369620
#
#      la_z_std  la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  \
# 634  0.086618     0.166570    0.479223    0.011959     0.179419    0.066693
# 220  0.439523     0.475903    3.242749    0.017483     0.611154    0.383549
# 426  0.531377     0.565245   10.143429    0.065769     0.751933    0.496027
# 428  0.255024     0.490962    3.530397    0.093105     0.549801    0.247532
# 72   0.944107     0.818615    8.734802    0.026848     1.124887    0.771740
#
#      label
# 634      1
# 220      1
# 426      1
# 428      1
# 72       1
#
# [5 rows x 42 columns]

# %%
# Define the output file path
output_file = 'kids.csv'

# Save the concatenated DataFrame to a CSV file
kids_data.to_csv(output_file, index=False)

print(f"Concatenated features saved to {output_file}")
# Out:
# Concatenated features saved to kids.csv

# %%
print(kids_data.columns)
# Out:
# Index(['id', 'ro_x_mean', 'ro_y_mean', 'ro_z_mean', 'ro_x_max', 'ro_y_max',
#        'ro_z_max', 'ro_x_min', 'ro_y_min', 'ro_z_min', 'ro_x_rmse',
#        'ro_y_rmse', 'ro_z_rmse', 'ro_x_std', 'ro_y_std', 'ro_z_std',
#        'ro_mag_mean', 'ro_mag_max', 'ro_mag_min', 'ro_mag_rmse', 'ro_mag_std',
#        'la_x_mean', 'la_y_mean', 'la_z_mean', 'la_x_max', 'la_y_max',
#        'la_z_max', 'la_x_min', 'la_y_min', 'la_z_min', 'la_x_rmse',
#        'la_y_rmse', 'la_z_rmse', 'la_x_std', 'la_y_std', 'la_z_std',
#        'la_mag_mean', 'la_mag_max', 'la_mag_min', 'la_mag_rmse', 'la_mag_std',
#        'label'],
#       dtype='object')
