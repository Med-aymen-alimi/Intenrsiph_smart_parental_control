# %% [markdown]
# ## Kids Data frame

# %%
#Librairie Importation:
import os
import pandas as pd

# %%
import os
import pandas as pd

def load_and_concat_sensor_data(root_dir, i):
    concatenated_data_frames = []

    # Get the dynamic folder that matches the pattern parent
    dynamic_folder = None
    for d in os.listdir(root_dir):
        if os.path.isdir(os.path.join(root_dir, d)) and 'parent' in d:
            dynamic_folder = d
            break

    if dynamic_folder is None:
        print("No folder matching the pattern '*_parent' found.")
        return concatenated_data_frames
    else:
        # Construct the full path to the dynamic folder
        dynamic_folder_path = os.path.join(root_dir, dynamic_folder).replace("\\", "/")

        # Sensor folders to process
        sensor_folders = ['Gyroscope','rotation', 'LinearAcceleration']

        # Construct paths to the sensor folders
        sensor_paths = {sensor: os.path.join(dynamic_folder_path, sensor).replace("\\", "/") for sensor in sensor_folders}

        # Check if sensor folders exist
        if not all(os.path.exists(sensor_path) for sensor_path in sensor_paths.values()):
            print(f"One or more sensor folders not found: {sensor_paths}")
            return concatenated_data_frames

        # Get the list of .txt files in each sensor folder (assuming they have the same number of files)
        sensor_files = {sensor: sorted([f for f in os.listdir(sensor_paths[sensor]) if f.endswith('.txt')]) for sensor in sensor_folders}

        # Iterate through the files and process them
        for Gyroscope_file,rotation_file, linear_acc_file in zip(sensor_files['Gyroscope'],sensor_files['rotation'], sensor_files['LinearAcceleration']):
            # Construct the full file paths
            Gyroscope_file_path = os.path.join(sensor_paths['Gyroscope'], Gyroscope_file).replace("\\", "/")
            rotation_file_path = os.path.join(sensor_paths['rotation'], rotation_file).replace("\\", "/")
            linear_acc_file_path = os.path.join(sensor_paths['LinearAcceleration'], linear_acc_file).replace("\\", "/")
             # Read the Gyroscope file into a DataFrame
            try:
                Gyroscope_df = pd.read_csv(Gyroscope_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                Gyroscope_df.columns = ['gy_timestamp', 'gy_internal_ts', 'gy_x', 'gy_y', 'gy_z', 'gy_app_id']
                # Calculate magnitude of gyroscope vector
                Gyroscope_df['gy_mag'] = (Gyroscope_df['gy_x']**2 + Gyroscope_df['gy_y']**2 + Gyroscope_df['gy_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {Gyroscope_file_path}: {e}")
                continue
            # Read the rotation file into a DataFrame
            try:
                rotation_df = pd.read_csv(rotation_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                rotation_df.columns = ['ro_timestamp', 'ro_internal_ts', 'ro_x', 'ro_y', 'ro_z', 'ro_app_id']
                # Calculate magnitude of rotation vector
                rotation_df['ro_mag'] = (rotation_df['ro_x']**2 + rotation_df['ro_y']**2 + rotation_df['ro_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {rotation_file_path}: {e}")
                continue
            
            # Read the linear acceleration file into a DataFrame
            try:
                linear_acc_df = pd.read_csv(linear_acc_file_path, delimiter='\t', header=None, usecols=[0, 1, 2, 3, 4, 5])
                linear_acc_df.columns = ['la_timestamp', 'la_internal_ts', 'la_x', 'la_y', 'la_z', 'la_app_id']
                # Calculate magnitude of linear acceleration vector
                linear_acc_df['la_mag'] = (linear_acc_df['la_x']**2 + linear_acc_df['la_y']**2 + linear_acc_df['la_z']**2)**0.5
            except Exception as e:
                print(f"Error reading {linear_acc_file_path}: {e}")
                continue

            # Concatenate the two DataFrames along columns
            concatenated_df = pd.concat([Gyroscope_df,rotation_df, linear_acc_df], axis=1)
            
            # Add 'id' and 'label' columns
            concatenated_df['id'] = i+25
            concatenated_df['label'] = 0
            
            # Append the concatenated DataFrame to the list
            concatenated_data_frames.append(concatenated_df)

    return concatenated_data_frames

# Example usage to load data for Kid1 to Kid25
root_base_dir = 'D:\internship\code\KidsOnThePhone_dataset\Parents'
parents_sensors = {}

for i in range(1, 26):
    root_dir = os.path.join(root_base_dir, f'Parent{i}', 'Sensors')
    parents_sensors[f"parent{i}_sensors"] = load_and_concat_sensor_data(root_dir, i)

# Display the first concatenated DataFrame for kid1_sensors
if "parent1_sensors" in parents_sensors and parents_sensors["parent1_sensors"]:
    print(parents_sensors["parent1_sensors"][0].head(1))
# Out:
#     gy_timestamp   gy_internal_ts      gy_x      gy_y      gy_z  gy_app_id  \
# 0  1498777468259  535121377667630 -0.004578  0.010895 -0.000671      105.0
#
#      gy_mag  ro_timestamp  ro_internal_ts      ro_x  ...    ro_mag  \
# 0  0.011836  1.498777e+12    5.351215e+14  0.256882  ...  0.424786
#
#     la_timestamp   la_internal_ts      la_x      la_y      la_z  la_app_id  \
# 0  1498777468262  535121377667630 -0.027222  0.030685  0.206451      105.0
#
#      la_mag  id  label
# 0  0.210487  26      0
#
# [1 rows x 23 columns]

# %%
print(len(parents_sensors["parent3_sensors"]))
# Out:
# 17

# %% [markdown]
# ## Data Preprocessing :

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 49
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# Processing parent4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# Processing parent7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 56
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 1309
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 49
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# Processing parent12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 49
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 49
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 70
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# Processing parent17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 42
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 63
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 56
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 49
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 21
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 434
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# Processing parent24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# Processing parent25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 35
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 28
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 14
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 7
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------

# %%
for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Drop duplicates and null values inplace
        df.drop_duplicates(inplace=True)
        df.dropna(inplace=True)
        
        # Count after dropping
        num_rows_after_cleaning = len(df)
        print(f"Number of rows after cleaning: {num_rows_after_cleaning}")
        
        print("-" * 30)
    
    # No need to append, directly modify the original list in parents_sensors[key]

    print(f"Finished processing {key}")
    print("=" * 40)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1694
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1286
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 173
# ------------------------------
# Finished processing parent1_sensors
# ========================================
# Processing parent2_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1717
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1504
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 22
# ------------------------------
# Finished processing parent2_sensors
# ========================================
# Processing parent3_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1725
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1746
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1711
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1765
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1156
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1026
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 143
# ------------------------------
# Finished processing parent3_sensors
# ========================================
# Processing parent4_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 993
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 24
# ------------------------------
# Finished processing parent4_sensors
# ========================================
# Processing parent5_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing parent5_sensors
# ========================================
# Processing parent6_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1430
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 741
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 183
# ------------------------------
# Finished processing parent6_sensors
# ========================================
# Processing parent7_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1743
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 745
# ------------------------------
# Finished processing parent7_sensors
# ========================================
# Processing parent8_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1489
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 197
# ------------------------------
# Finished processing parent8_sensors
# ========================================
# Processing parent9_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1551
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 743
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 11
# ------------------------------
# Finished processing parent9_sensors
# ========================================
# Processing parent10_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 33:
# Number of rows after cleaning: 197
# ------------------------------
# Finished processing parent10_sensors
# ========================================
# Processing parent11_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 744
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 28
# ------------------------------
# Finished processing parent11_sensors
# ========================================
# Processing parent12_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1727
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1748
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 496
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 186
# ------------------------------
# Finished processing parent12_sensors
# ========================================
# Processing parent13_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# Finished processing parent13_sensors
# ========================================
# Processing parent14_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 496
# ------------------------------
# Finished processing parent14_sensors
# ========================================
# Processing parent15_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 993
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 126
# ------------------------------
# Finished processing parent15_sensors
# ========================================
# Processing parent16_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1697
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 510
# ------------------------------
# Finished processing parent16_sensors
# ========================================
# Processing parent17_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1241
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 102
# ------------------------------
# Finished processing parent17_sensors
# ========================================
# Processing parent18_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 744
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 4
# ------------------------------
# Finished processing parent18_sensors
# ========================================
# Processing parent19_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 248
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 88
# ------------------------------
# Finished processing parent19_sensors
# ========================================
# Processing parent20_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 736
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 87
# ------------------------------
# Finished processing parent20_sensors
# ========================================
# Processing parent21_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1740
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 250
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 207
# ------------------------------
# Finished processing parent21_sensors
# ========================================
# Processing parent22_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1613
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1864
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1734
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1742
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1714
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1762
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1726
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1750
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1735
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1282
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 368
# ------------------------------
# Finished processing parent22_sensors
# ========================================
# Processing parent23_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1730
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 1736
# ------------------------------
# DataFrame 15:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 16:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 17:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 18:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 19:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 20:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 21:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 22:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 23:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 24:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 25:
# Number of rows after cleaning: 1717
# ------------------------------
# DataFrame 26:
# Number of rows after cleaning: 1757
# ------------------------------
# DataFrame 27:
# Number of rows after cleaning: 1745
# ------------------------------
# DataFrame 28:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 29:
# Number of rows after cleaning: 1608
# ------------------------------
# DataFrame 30:
# Number of rows after cleaning: 1864
# ------------------------------
# DataFrame 31:
# Number of rows after cleaning: 1435
# ------------------------------
# DataFrame 32:
# Number of rows after cleaning: 6
# ------------------------------
# Finished processing parent23_sensors
# ========================================
# Processing parent24_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 1739
# ------------------------------
# DataFrame 14:
# Number of rows after cleaning: 214
# ------------------------------
# Finished processing parent24_sensors
# ========================================
# Processing parent25_sensors:
# DataFrame 1:
# Number of rows after cleaning: 1732
# ------------------------------
# DataFrame 2:
# Number of rows after cleaning: 1731
# ------------------------------
# DataFrame 3:
# Number of rows after cleaning: 1744
# ------------------------------
# DataFrame 4:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 5:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 6:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 7:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 8:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 9:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 10:
# Number of rows after cleaning: 1738
# ------------------------------
# DataFrame 11:
# Number of rows after cleaning: 1737
# ------------------------------
# DataFrame 12:
# Number of rows after cleaning: 745
# ------------------------------
# DataFrame 13:
# Number of rows after cleaning: 20
# ------------------------------
# Finished processing parent25_sensors
# ========================================

# %%
# Example usage assuming `kids_sensors` dictionary is populated as before

for key, data_frames in parents_sensors.items():
    print(f"Processing {key}:")
    for df_idx, df in enumerate(data_frames):
        print(f"DataFrame {df_idx + 1}:")
        
        # Count duplicates
        num_duplicates = df.duplicated().sum()
        print(f"Number of duplicates: {num_duplicates}")
        
        # Count null values
        num_null_values = df.isnull().sum().sum()
        print(f"Number of null values: {num_null_values}")
        
        print("-" * 30)
# Out:
# Processing parent1_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent2_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent3_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent4_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent5_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent6_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent7_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent8_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent9_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent10_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 33:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent11_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent12_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent13_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent14_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent15_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent16_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent17_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent18_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent19_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent20_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent21_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent22_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent23_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 15:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 16:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 17:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 18:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 19:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 20:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 21:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 22:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 23:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 24:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 25:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 26:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 27:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 28:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 29:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 30:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 31:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 32:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent24_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 14:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# Processing parent25_sensors:
# DataFrame 1:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 2:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 3:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 4:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 5:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 6:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 7:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 8:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 9:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 10:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 11:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 12:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------
# DataFrame 13:
# Number of duplicates: 0
# Number of null values: 0
# ------------------------------

# %%
print(parents_sensors["parent2_sensors"][2].head(30))
# Out:
#      gy_timestamp  gy_internal_ts      gy_x      gy_y      gy_z  gy_app_id  \
# 0   1499364820286  67771092179883  0.007370  0.013000 -0.004272       95.0
# 1   1499364820308  67771112321485  0.004196  0.003281 -0.001831       95.0
# 2   1499364820321  67771132463087  0.000351  0.000778  0.002838       95.0
# 3   1499364820339  67771152604688  0.003647 -0.000076 -0.004837       95.0
# 4   1499364820357  67771172746290  0.006683 -0.005646 -0.001480       95.0
# 5   1499364820374  67771192887891 -0.004929 -0.004913 -0.008347       95.0
# 6   1499364820391  67771213029493  0.004547  0.013824 -0.005630       95.0
# 7   1499364820427  67771233171094 -0.012421  0.019547 -0.001587       95.0
# 8   1499364820444  67771253312696  0.004608  0.010529 -0.013657       95.0
# 9   1499364820462  67771273454298  0.012787 -0.002823  0.003860       95.0
# 10  1499364820480  67771293595899  0.014999 -0.010025  0.006866       95.0
# 11  1499364820497  67771313737501  0.005737  0.000290  0.002502       95.0
# 12  1499364820515  67771333879102 -0.000854  0.008545 -0.009232       95.0
# 13  1499364820532  67771354020704  0.015121 -0.008636  0.005478       95.0
# 14  1499364820571  67771374162305  0.003571 -0.011902 -0.001236       95.0
# 15  1499364820585  67771394303907 -0.003952 -0.003464  0.005936       95.0
# 16  1499364820603  67771414445508 -0.008408 -0.003876  0.002274       95.0
# 17  1499364820621  67771434587110 -0.008377 -0.002655 -0.001312       95.0
# 18  1499364820638  67771454728712 -0.005325 -0.002136 -0.002838       95.0
# 19  1499364820656  67771474870313  0.005905  0.014252 -0.000198       95.0
# 20  1499364820673  67771495011915  0.008530  0.010986  0.001007       95.0
# 21  1499364820709  67771515153516  0.005768  0.010895 -0.016830       95.0
# 22  1499364820726  67771535295118  0.005890 -0.005371 -0.010040       95.0
# 23  1499364820744  67771555436719  0.016708 -0.008286 -0.000412       95.0
# 24  1499364820762  67771575578321  0.008194 -0.021500 -0.001144       95.0
# 25  1499364820779  67771595719923  0.019577  0.007645 -0.002182       95.0
# 26  1499364820797  67771615861524  0.027771  0.025146 -0.007263       95.0
# 27  1499364820815  67771636003126  0.015488  0.030640 -0.020737       95.0
# 28  1499364820850  67771656144727  0.009705  0.032547 -0.031250       95.0
# 29  1499364820867  67771676286329 -0.025314 -0.022049 -0.002457       95.0
#
#       gy_mag   ro_timestamp  ro_internal_ts      ro_x  ...    ro_mag  \
# 0   0.015543  1499364820294  67771112321485  0.110077  ...  0.984454
# 1   0.005632  1499364820311  67771132463087  0.110062  ...  0.984456
# 2   0.002964  1499364820347  67771152604688  0.109955  ...  0.984534
# 3   0.006058  1499364820364  67771172746290  0.109848  ...  0.984558
# 4   0.008873  1499364820381  67771192887891  0.109879  ...  0.984538
# 5   0.010867  1499364820399  67771213029493  0.109985  ...  0.984511
# 6   0.015604  1499364820417  67771233171094  0.110001  ...  0.984484
# 7   0.023213  1499364820434  67771253312696  0.109894  ...  0.984520
# 8   0.017849  1499364820452  67771273454298  0.109909  ...  0.984522
# 9   0.013652  1499364820487  67771293595899  0.109940  ...  0.984522
# 10  0.019304  1499364820506  67771313737501  0.109863  ...  0.984559
# 11  0.006266  1499364820522  67771333879102  0.109818  ...  0.984568
# 12  0.012608  1499364820540  67771354020704  0.109756  ...  0.984576
# 13  0.018255  1499364820558  67771374162305  0.109650  ...  0.984612
# 14  0.012487  1499364820575  67771394303907  0.109650  ...  0.984637
# 15  0.007928  1499364820593  67771414445508  0.109741  ...  0.984590
# 16  0.009533  1499364820628  67771434587110  0.109680  ...  0.984596
# 17  0.008885  1499364820646  67771454728712  0.109680  ...  0.984614
# 18  0.006401  1499364820664  67771474870313  0.109665  ...  0.984612
# 19  0.015428  1499364820681  67771495011915  0.109634  ...  0.984642
# 20  0.013945  1499364820698  67771515153516  0.109650  ...  0.984640
# 21  0.020862  1499364820717  67771535295118  0.109680  ...  0.984606
# 22  0.012820  1499364820734  67771555436719  0.109695  ...  0.984619
# 23  0.018654  1499364820770  67771575578321  0.109756  ...  0.984608
# 24  0.023037  1499364820787  67771595719923  0.109726  ...  0.984659
# 25  0.021130  1499364820811  67771615861524  0.109604  ...  0.984687
# 26  0.038162  1499364820822  67771636003126  0.109375  ...  0.984727
# 27  0.040108  1499364820840  67771656144727  0.109009  ...  0.984688
# 28  0.046152  1499364820857  67771676286329  0.108887  ...  0.984657
# 29  0.033660  1499364820888  67771696427930  0.108994  ...  0.984646
#
#      la_timestamp  la_internal_ts      la_x      la_y      la_z  la_app_id  \
# 0   1499364820288  67771092179883  0.014343  0.104004  0.120438       95.0
# 1   1499364820309  67771112321485  0.001511  0.058853  0.107605       95.0
# 2   1499364820322  67771132463087  0.040543  0.090286  0.149353       95.0
# 3   1499364820340  67771152604688 -0.087860  0.148575  0.178391       95.0
# 4   1499364820358  67771172746290 -0.048981  0.222885  0.101791       95.0
# 5   1499364820376  67771192887891  0.104813  0.055115  0.147583       95.0
# 6   1499364820393  67771213029493  0.017868  0.106842 -0.041687       95.0
# 7   1499364820429  67771233171094  0.047714  0.003891 -0.018158       95.0
# 8   1499364820446  67771253312696 -0.007599  0.152969  0.229553       95.0
# 9   1499364820463  67771273454298 -0.003143  0.119598  0.214767       95.0
# 10  1499364820481  67771293595899  0.015732  0.144012  0.021042       95.0
# 11  1499364820498  67771313737501  0.021820  0.055328 -0.015274       95.0
# 12  1499364820516  67771333879102 -0.014084  0.080414  0.080841       95.0
# 13  1499364820534  67771354020704  0.022049  0.074112  0.080383       95.0
# 14  1499364820573  67771374162305 -0.082230  0.148865  0.101456       95.0
# 15  1499364820587  67771394303907  0.004974  0.140991  0.090622       95.0
# 16  1499364820604  67771414445508 -0.047012  0.156784  0.136551       95.0
# 17  1499364820622  67771434587110 -0.003937  0.097061  0.230179       95.0
# 18  1499364820640  67771454728712  0.074982  0.122223  0.100983       95.0
# 19  1499364820657  67771474870313  0.056732  0.104034  0.046616       95.0
# 20  1499364820675  67771495011915  0.022934  0.140472  0.017883       95.0
# 21  1499364820710  67771515153516  0.037598  0.137024  0.063736       95.0
# 22  1499364820728  67771535295118  0.053726  0.086121  0.054626       95.0
# 23  1499364820745  67771555436719  0.006454  0.130295  0.143051       95.0
# 24  1499364820763  67771575578321  0.003708  0.110352  0.092789       95.0
# 25  1499364820780  67771595719923  0.120224  0.117126  0.044540       95.0
# 26  1499364820811  67771615861524  0.067673  0.030991  0.131195       95.0
# 27  1499364820817  67771636003126  0.016403  0.037125 -0.014389       95.0
# 28  1499364820851  67771656144727 -0.059143  0.098541  0.106995       95.0
# 29  1499364820869  67771676286329 -0.136612  0.233093  0.113876       95.0
#
#       la_mag  id  label
# 0   0.159774  27      0
# 1   0.122657  27      0
# 2   0.179169  27      0
# 3   0.248228  27      0
# 4   0.249877  27      0
# 5   0.189220  27      0
# 6   0.116070  27      0
# 7   0.051201  27      0
# 8   0.275957  27      0
# 9   0.245843  27      0
# 10  0.146389  27      0
# 11  0.061406  27      0
# 12  0.114891  27      0
# 13  0.111536  27      0
# 14  0.198029  27      0
# 15  0.167677  27      0
# 16  0.213161  27      0
# 17  0.249837  27      0
# 18  0.175380  27      0
# 19  0.127337  27      0
# 20  0.143451  27      0
# 21  0.155729  27      0
# 22  0.115271  27      0
# 23  0.193603  27      0
# 24  0.144225  27      0
# 25  0.173656  27      0
# 26  0.150838  27      0
# 27  0.043062  27      0
# 28  0.157023  27      0
# 29  0.293195  27      0
#
# [30 rows x 23 columns]

# %%
import numpy as np
import pandas as pd

# Initialize the dictionary to store extracted features
extracted_features = {}

# Iterate through each key (e.g., 'kid1_sensors', 'kid2_sensors', etc.) in kids_sensors
for key, data_frames in parents_sensors.items():
    # Initialize lists to store feature values for each DataFrame
    ids = []
    ro_x_means = []
    ro_y_means = []
    ro_z_means = []
    ro_x_maxs = []
    ro_y_maxs = []
    ro_z_maxs = []
    ro_x_mins = []
    ro_y_mins = []
    ro_z_mins = []
    ro_x_rmse = []
    ro_y_rmse = []
    ro_z_rmse = []
    ro_x_stds = []
    ro_y_stds = []
    ro_z_stds = []
    la_x_means = []
    la_y_means = []
    la_z_means = []
    la_x_maxs = []
    la_y_maxs = []
    la_z_maxs = []
    la_x_mins = []
    la_y_mins = []
    la_z_mins = []
    la_x_rmse = []
    la_y_rmse = []
    la_z_rmse = []
    la_x_stds = []
    la_y_stds = []
    la_z_stds = []
    ro_mag_means = []
    ro_mag_maxs = []
    ro_mag_mins = []
    ro_mag_rmse = []
    ro_mag_stds = []
    la_mag_means = []
    la_mag_maxs = []
    la_mag_mins = []
    la_mag_rmse = []
    la_mag_stds = []
    
    gy_x_means = []
    gy_y_means = []
    gy_z_means = []
    gy_x_maxs = []
    gy_y_maxs = []
    gy_z_maxs = []
    gy_x_mins = []
    gy_y_mins = []
    gy_z_mins = []
    gy_x_rmse = []
    gy_y_rmse = []
    gy_z_rmse = []
    gy_x_stds = []
    gy_y_stds = []
    gy_z_stds = []
    gy_mag_means = []
    gy_mag_maxs = []
    gy_mag_mins = []
    gy_mag_rmse = []
    gy_mag_stds = []
    labels = []
    
    # Iterate through each DataFrame in the current key's list of DataFrames
    for df in data_frames:
        # Extract id and label (assuming they are the same for rotation and linear acceleration)
        ids.append(df['id'].iloc[0])
        
        
        #Extract features for gyroscope:
        gy_x_means.append(df['gy_x'].mean())
        gy_y_means.append(df['gy_y'].mean())
        gy_z_means.append(df['gy_z'].mean())
        gy_x_maxs.append(df['gy_x'].max())
        gy_y_maxs.append(df['gy_y'].max())
        gy_z_maxs.append(df['gy_z'].max())
        gy_x_mins.append(df['gy_x'].min())
        gy_y_mins.append(df['gy_y'].min())
        gy_z_mins.append(df['gy_z'].min())
        gy_x_rmse.append(np.sqrt(np.mean(df['gy_x']**2)))
        gy_y_rmse.append(np.sqrt(np.mean(df['gy_y']**2)))
        gy_z_rmse.append(np.sqrt(np.mean(df['gy_z']**2)))
        gy_x_stds.append(df['gy_x'].std())
        gy_y_stds.append(df['gy_y'].std())
        gy_z_stds.append(df['gy_z'].std())

        gy_mag_means.append(df['gy_mag'].mean())
        gy_mag_maxs.append(df['gy_mag'].max())
        gy_mag_mins.append(df['gy_mag'].min())
        gy_mag_rmse.append(np.sqrt(np.mean(df['gy_mag']**2)))
        gy_mag_stds.append(df['gy_mag'].std())

        # Extract features for rotation
        ro_x_means.append(df['ro_x'].mean())
        ro_y_means.append(df['ro_y'].mean())
        ro_z_means.append(df['ro_z'].mean())
        ro_x_maxs.append(df['ro_x'].max())
        ro_y_maxs.append(df['ro_y'].max())
        ro_z_maxs.append(df['ro_z'].max())
        ro_x_mins.append(df['ro_x'].min())
        ro_y_mins.append(df['ro_y'].min())
        ro_z_mins.append(df['ro_z'].min())
        ro_x_rmse.append(np.sqrt(np.mean(df['ro_x']**2)))
        ro_y_rmse.append(np.sqrt(np.mean(df['ro_y']**2)))
        ro_z_rmse.append(np.sqrt(np.mean(df['ro_z']**2)))
        ro_x_stds.append(df['ro_x'].std())
        ro_y_stds.append(df['ro_y'].std())
        ro_z_stds.append(df['ro_z'].std())
        ro_mag_means.append(df['ro_mag'].mean())
        ro_mag_maxs.append(df['ro_mag'].max())
        ro_mag_mins.append(df['ro_mag'].min())
        ro_mag_rmse.append(np.sqrt(np.mean(df['ro_mag']**2)))
        ro_mag_stds.append(df['ro_mag'].std())
        
        # Extract features for linear acceleration
        la_x_means.append(df['la_x'].mean())
        la_y_means.append(df['la_y'].mean())
        la_z_means.append(df['la_z'].mean())
        la_x_maxs.append(df['la_x'].max())
        la_y_maxs.append(df['la_y'].max())
        la_z_maxs.append(df['la_z'].max())
        la_x_mins.append(df['la_x'].min())
        la_y_mins.append(df['la_y'].min())
        la_z_mins.append(df['la_z'].min())
        la_x_rmse.append(np.sqrt(np.mean(df['la_x']**2)))
        la_y_rmse.append(np.sqrt(np.mean(df['la_y']**2)))
        la_z_rmse.append(np.sqrt(np.mean(df['la_z']**2)))
        la_x_stds.append(df['la_x'].std())
        la_y_stds.append(df['la_y'].std())
        la_z_stds.append(df['la_z'].std())

        # Compute la_mag and extract features
        #la_mag = np.sqrt(df['la_x']**2 + df['la_y']**2 + df['la_z']**2)
        la_mag_means.append(df['la_mag'].mean())
        la_mag_maxs.append(df['la_mag'].max())
        la_mag_mins.append(df['la_mag'].min())
        la_mag_rmse.append(np.sqrt(np.mean(df['la_mag']**2)))
        la_mag_stds.append(df['la_mag'].std())

        # Extract label (assuming it's the same for all rows in this DataFrame)
        labels.append(df['label'].iloc[0])
    
    # Create a DataFrame for extracted features for the current key
    extracted_df = pd.DataFrame({
        'id': ids,
        'gy_x_mean': gy_x_means,
        'gy_y_mean': gy_y_means,
        'gy_z_mean': gy_z_means,
        'gy_x_max': gy_x_maxs,
        'gy_y_max': gy_y_maxs,
        'gy_z_max': gy_z_maxs,
        'gy_x_min': gy_x_mins,
        'gy_y_min': gy_y_mins,
        'gy_z_min': gy_z_mins,
        'gy_x_rmse': gy_x_rmse,
        'gy_y_rmse': gy_y_rmse,
        'gy_z_rmse': gy_z_rmse,
        'gy_x_std': gy_x_stds,
        'gy_y_std': gy_y_stds,
        'gy_z_std': gy_z_stds,
        'gy_mag_mean': gy_mag_means,
        'gy_mag_max': gy_mag_maxs,
        'gy_mag_min': gy_mag_mins,
        'gy_mag_rmse': gy_mag_rmse,
        'gy_mag_std': gy_mag_stds,
        'ro_x_mean': ro_x_means,
        'ro_y_mean': ro_y_means,
        'ro_z_mean': ro_z_means,
        'ro_x_max': ro_x_maxs,
        'ro_y_max': ro_y_maxs,
        'ro_z_max': ro_z_maxs,
        'ro_x_min': ro_x_mins,
        'ro_y_min': ro_y_mins,
        'ro_z_min': ro_z_mins,
        'ro_x_rmse': ro_x_rmse,
        'ro_y_rmse': ro_y_rmse,
        'ro_z_rmse': ro_z_rmse,
        'ro_x_std': ro_x_stds,
        'ro_y_std': ro_y_stds,
        'ro_z_std': ro_z_stds,
        'ro_mag_mean': ro_mag_means,
        'ro_mag_max': ro_mag_maxs,
        'ro_mag_min': ro_mag_mins,
        'ro_mag_rmse': ro_mag_rmse,
        'ro_mag_std': ro_mag_stds,
        'la_x_mean': la_x_means,
        'la_y_mean': la_y_means,
        'la_z_mean': la_z_means,
        'la_x_max': la_x_maxs,
        'la_y_max': la_y_maxs,
        'la_z_max': la_z_maxs,
        'la_x_min': la_x_mins,
        'la_y_min': la_y_mins,
        'la_z_min': la_z_mins,
        'la_x_rmse': la_x_rmse,
        'la_y_rmse': la_y_rmse,
        'la_z_rmse': la_z_rmse,
        'la_x_std': la_x_stds,
        'la_y_std': la_y_stds,
        'la_z_std': la_z_stds,
        'la_mag_mean': la_mag_means,
        'la_mag_max': la_mag_maxs,
        'la_mag_min': la_mag_mins,
        'la_mag_rmse': la_mag_rmse,
        'la_mag_std': la_mag_stds,
        'label': labels
    })
    
    # Assign the DataFrame to the corresponding key in extracted_features dictionary
    extracted_features[key] = extracted_df

# Example usage to print the first few rows of the extracted DataFrame for 'kid1_sensors'
if "parent1_sensors" in extracted_features and not extracted_features["parent1_sensors"].empty:
    print(extracted_features["parent1_sensors"].head())
# Out:
#    id  gy_x_mean  gy_y_mean  gy_z_mean  gy_x_max  gy_y_max  gy_z_max  \
# 0  26   0.005382   0.006229   0.051065  1.174347  3.238022  3.445114
# 1  26   0.008800   0.004438   0.004971  0.307037  0.216614  0.101822
# 2  26   0.005707   0.003812   0.002290  0.432327  0.328430  0.272812
# 3  26  -0.002370   0.002397  -0.000705  0.368118  0.332596  0.101059
# 4  26   0.000099  -0.001993   0.002131  0.360596  0.184464  0.239471
#
#    gy_x_min  gy_y_min  gy_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0 -1.057114 -2.686401 -0.277649  ...   0.272019  0.252229  0.212338  0.269916
# 1 -0.237183 -0.220490 -0.073425  ...   0.143083  0.073080  0.085827  0.142348
# 2 -0.384491 -0.300980 -0.203369  ...   0.174780  0.126461  0.119795  0.172402
# 3 -0.306839 -0.269043 -0.113281  ...   0.167808  0.081594  0.075217  0.159663
# 4 -0.318146 -0.254562 -0.250671  ...   0.152900  0.085408  0.116846  0.138199
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.267800    5.266115    0.008873     0.431195    0.338051      0
# 1     0.174610    1.067860    0.031145     0.207902    0.112880      0
# 2     0.200093    1.779876    0.011244     0.258935    0.164396      0
# 3     0.155247    1.392207    0.006894     0.205683    0.134961      0
# 4     0.165405    1.494733    0.014091     0.213393    0.134863      0
#
# [5 rows x 62 columns]

# %%
print(extracted_features["parent1_sensors"].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 62 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           18 non-null     int64
#  1   gy_x_mean    18 non-null     float64
#  2   gy_y_mean    18 non-null     float64
#  3   gy_z_mean    18 non-null     float64
#  4   gy_x_max     18 non-null     float64
#  5   gy_y_max     18 non-null     float64
#  6   gy_z_max     18 non-null     float64
#  7   gy_x_min     18 non-null     float64
#  8   gy_y_min     18 non-null     float64
#  9   gy_z_min     18 non-null     float64
#  10  gy_x_rmse    18 non-null     float64
#  11  gy_y_rmse    18 non-null     float64
#  12  gy_z_rmse    18 non-null     float64
#  13  gy_x_std     18 non-null     float64
#  14  gy_y_std     18 non-null     float64
#  15  gy_z_std     18 non-null     float64
#  16  gy_mag_mean  18 non-null     float64
#  17  gy_mag_max   18 non-null     float64
#  18  gy_mag_min   18 non-null     float64
#  19  gy_mag_rmse  18 non-null     float64
#  20  gy_mag_std   18 non-null     float64
#  21  ro_x_mean    18 non-null     float64
#  22  ro_y_mean    18 non-null     float64
#  23  ro_z_mean    18 non-null     float64
#  24  ro_x_max     18 non-null     float64
#  25  ro_y_max     18 non-null     float64
#  26  ro_z_max     18 non-null     float64
#  27  ro_x_min     18 non-null     float64
#  28  ro_y_min     18 non-null     float64
#  29  ro_z_min     18 non-null     float64
#  30  ro_x_rmse    18 non-null     float64
#  31  ro_y_rmse    18 non-null     float64
#  32  ro_z_rmse    18 non-null     float64
#  33  ro_x_std     18 non-null     float64
#  34  ro_y_std     18 non-null     float64
#  35  ro_z_std     18 non-null     float64
#  36  ro_mag_mean  18 non-null     float64
#  37  ro_mag_max   18 non-null     float64
#  38  ro_mag_min   18 non-null     float64
#  39  ro_mag_rmse  18 non-null     float64
#  40  ro_mag_std   18 non-null     float64
#  41  la_x_mean    18 non-null     float64
#  42  la_y_mean    18 non-null     float64
#  43  la_z_mean    18 non-null     float64
#  44  la_x_max     18 non-null     float64
#  45  la_y_max     18 non-null     float64
#  46  la_z_max     18 non-null     float64
#  47  la_x_min     18 non-null     float64
#  48  la_y_min     18 non-null     float64
#  49  la_z_min     18 non-null     float64
#  50  la_x_rmse    18 non-null     float64
#  51  la_y_rmse    18 non-null     float64
#  52  la_z_rmse    18 non-null     float64
#  53  la_x_std     18 non-null     float64
#  54  la_y_std     18 non-null     float64
#  55  la_z_std     18 non-null     float64
#  56  la_mag_mean  18 non-null     float64
#  57  la_mag_max   18 non-null     float64
#  58  la_mag_min   18 non-null     float64
#  59  la_mag_rmse  18 non-null     float64
#  60  la_mag_std   18 non-null     float64
#  61  label        18 non-null     int64
# dtypes: float64(60), int64(2)
# memory usage: 8.8 KB
# None

# %%
keys = extracted_features.keys()
print("Keys:")
for key in keys:
    print(key)
print(len(extracted_features))
# Out:
# Keys:
# parent1_sensors
# parent2_sensors
# parent3_sensors
# parent4_sensors
# parent5_sensors
# parent6_sensors
# parent7_sensors
# parent8_sensors
# parent9_sensors
# parent10_sensors
# parent11_sensors
# parent12_sensors
# parent13_sensors
# parent14_sensors
# parent15_sensors
# parent16_sensors
# parent17_sensors
# parent18_sensors
# parent19_sensors
# parent20_sensors
# parent21_sensors
# parent22_sensors
# parent23_sensors
# parent24_sensors
# parent25_sensors
# 25

# %%
# Concatenate all data frames into a single data frame
parents_data = pd.concat(extracted_features.values(), ignore_index=True)

# %%
print(parents_data.head(5))
print(parents_data.info())
# Out:
#    id  gy_x_mean  gy_y_mean  gy_z_mean  gy_x_max  gy_y_max  gy_z_max  \
# 0  26   0.005382   0.006229   0.051065  1.174347  3.238022  3.445114
# 1  26   0.008800   0.004438   0.004971  0.307037  0.216614  0.101822
# 2  26   0.005707   0.003812   0.002290  0.432327  0.328430  0.272812
# 3  26  -0.002370   0.002397  -0.000705  0.368118  0.332596  0.101059
# 4  26   0.000099  -0.001993   0.002131  0.360596  0.184464  0.239471
#
#    gy_x_min  gy_y_min  gy_z_min  ...  la_z_rmse  la_x_std  la_y_std  la_z_std  \
# 0 -1.057114 -2.686401 -0.277649  ...   0.272019  0.252229  0.212338  0.269916
# 1 -0.237183 -0.220490 -0.073425  ...   0.143083  0.073080  0.085827  0.142348
# 2 -0.384491 -0.300980 -0.203369  ...   0.174780  0.126461  0.119795  0.172402
# 3 -0.306839 -0.269043 -0.113281  ...   0.167808  0.081594  0.075217  0.159663
# 4 -0.318146 -0.254562 -0.250671  ...   0.152900  0.085408  0.116846  0.138199
#
#    la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  label
# 0     0.267800    5.266115    0.008873     0.431195    0.338051      0
# 1     0.174610    1.067860    0.031145     0.207902    0.112880      0
# 2     0.200093    1.779876    0.011244     0.258935    0.164396      0
# 3     0.155247    1.392207    0.006894     0.205683    0.134961      0
# 4     0.165405    1.494733    0.014091     0.213393    0.134863      0
#
# [5 rows x 62 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537 entries, 0 to 536
# Data columns (total 62 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           537 non-null    int64
#  1   gy_x_mean    537 non-null    float64
#  2   gy_y_mean    537 non-null    float64
#  3   gy_z_mean    537 non-null    float64
#  4   gy_x_max     537 non-null    float64
#  5   gy_y_max     537 non-null    float64
#  6   gy_z_max     537 non-null    float64
#  7   gy_x_min     537 non-null    float64
#  8   gy_y_min     537 non-null    float64
#  9   gy_z_min     537 non-null    float64
#  10  gy_x_rmse    537 non-null    float64
#  11  gy_y_rmse    537 non-null    float64
#  12  gy_z_rmse    537 non-null    float64
#  13  gy_x_std     537 non-null    float64
#  14  gy_y_std     537 non-null    float64
#  15  gy_z_std     537 non-null    float64
#  16  gy_mag_mean  537 non-null    float64
#  17  gy_mag_max   537 non-null    float64
#  18  gy_mag_min   537 non-null    float64
#  19  gy_mag_rmse  537 non-null    float64
#  20  gy_mag_std   537 non-null    float64
#  21  ro_x_mean    537 non-null    float64
#  22  ro_y_mean    537 non-null    float64
#  23  ro_z_mean    537 non-null    float64
#  24  ro_x_max     537 non-null    float64
#  25  ro_y_max     537 non-null    float64
#  26  ro_z_max     537 non-null    float64
#  27  ro_x_min     537 non-null    float64
#  28  ro_y_min     537 non-null    float64
#  29  ro_z_min     537 non-null    float64
#  30  ro_x_rmse    537 non-null    float64
#  31  ro_y_rmse    537 non-null    float64
#  32  ro_z_rmse    537 non-null    float64
#  33  ro_x_std     537 non-null    float64
#  34  ro_y_std     537 non-null    float64
#  35  ro_z_std     537 non-null    float64
#  36  ro_mag_mean  537 non-null    float64
#  37  ro_mag_max   537 non-null    float64
#  38  ro_mag_min   537 non-null    float64
#  39  ro_mag_rmse  537 non-null    float64
#  40  ro_mag_std   537 non-null    float64
#  41  la_x_mean    537 non-null    float64
#  42  la_y_mean    537 non-null    float64
#  43  la_z_mean    537 non-null    float64
#  44  la_x_max     537 non-null    float64
#  45  la_y_max     537 non-null    float64
#  46  la_z_max     537 non-null    float64
#  47  la_x_min     537 non-null    float64
#  48  la_y_min     537 non-null    float64
#  49  la_z_min     537 non-null    float64
#  50  la_x_rmse    537 non-null    float64
#  51  la_y_rmse    537 non-null    float64
#  52  la_z_rmse    537 non-null    float64
#  53  la_x_std     537 non-null    float64
#  54  la_y_std     537 non-null    float64
#  55  la_z_std     537 non-null    float64
#  56  la_mag_mean  537 non-null    float64
#  57  la_mag_max   537 non-null    float64
#  58  la_mag_min   537 non-null    float64
#  59  la_mag_rmse  537 non-null    float64
#  60  la_mag_std   537 non-null    float64
#  61  label        537 non-null    int64
# dtypes: float64(60), int64(2)
# memory usage: 260.2 KB
# None

# %%
parents_data = parents_data.sample(frac=1, random_state=42)
print(parents_data.head())
print(parents_data.info())
# Out:
#      id  gy_x_mean  gy_y_mean  gy_z_mean  gy_x_max  gy_y_max  gy_z_max  \
# 492  48   0.000348   0.002910  -0.000850  0.418884  0.459259  0.210815
# 73   30   0.002272  -0.012039  -0.007248  1.880066  1.704865  2.950195
# 347  41   0.003260  -0.000773  -0.006397  1.411987  1.252014  0.956192
# 86   30  -0.001534  -0.010550  -0.004989  1.679184  2.591125  0.811890
# 455  47   0.002003   0.005221   0.002339  0.644150  0.716812  0.144119
#
#      gy_x_min  gy_y_min  gy_z_min  ...  la_z_rmse  la_x_std  la_y_std  \
# 492 -0.233932 -0.460510 -0.166946  ...   0.221468  0.101556  0.084982
# 73  -1.254150 -2.425674 -2.551514  ...   0.339864  0.284197  0.270438
# 347 -1.080002 -1.137497 -2.412109  ...   0.509941  0.386451  0.270622
# 86  -1.801025 -1.770065 -1.156448  ...   0.334336  0.296876  0.241595
# 455 -0.370361 -1.000702 -0.126953  ...   0.258236  0.097325  0.086917
#
#      la_z_std  la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  \
# 492  0.152481     0.247567    1.636423    0.013640     0.277736    0.125924
# 73   0.319180     0.370789    2.830894    0.018770     0.519997    0.364677
# 347  0.478304     0.499345    8.740907    0.026615     0.700391    0.491265
# 86   0.326020     0.400716    3.196270    0.028532     0.523797    0.337425
# 455  0.216791     0.245036    2.810417    0.019456     0.305095    0.181823
#
#      label
# 492      0
# 73       0
# 347      0
# 86       0
# 455      0
#
# [5 rows x 62 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 492 to 102
# Data columns (total 62 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           537 non-null    int64
#  1   gy_x_mean    537 non-null    float64
#  2   gy_y_mean    537 non-null    float64
#  3   gy_z_mean    537 non-null    float64
#  4   gy_x_max     537 non-null    float64
#  5   gy_y_max     537 non-null    float64
#  6   gy_z_max     537 non-null    float64
#  7   gy_x_min     537 non-null    float64
#  8   gy_y_min     537 non-null    float64
#  9   gy_z_min     537 non-null    float64
#  10  gy_x_rmse    537 non-null    float64
#  11  gy_y_rmse    537 non-null    float64
#  12  gy_z_rmse    537 non-null    float64
#  13  gy_x_std     537 non-null    float64
#  14  gy_y_std     537 non-null    float64
#  15  gy_z_std     537 non-null    float64
#  16  gy_mag_mean  537 non-null    float64
#  17  gy_mag_max   537 non-null    float64
#  18  gy_mag_min   537 non-null    float64
#  19  gy_mag_rmse  537 non-null    float64
#  20  gy_mag_std   537 non-null    float64
#  21  ro_x_mean    537 non-null    float64
#  22  ro_y_mean    537 non-null    float64
#  23  ro_z_mean    537 non-null    float64
#  24  ro_x_max     537 non-null    float64
#  25  ro_y_max     537 non-null    float64
#  26  ro_z_max     537 non-null    float64
#  27  ro_x_min     537 non-null    float64
#  28  ro_y_min     537 non-null    float64
#  29  ro_z_min     537 non-null    float64
#  30  ro_x_rmse    537 non-null    float64
#  31  ro_y_rmse    537 non-null    float64
#  32  ro_z_rmse    537 non-null    float64
#  33  ro_x_std     537 non-null    float64
#  34  ro_y_std     537 non-null    float64
#  35  ro_z_std     537 non-null    float64
#  36  ro_mag_mean  537 non-null    float64
#  37  ro_mag_max   537 non-null    float64
#  38  ro_mag_min   537 non-null    float64
#  39  ro_mag_rmse  537 non-null    float64
#  40  ro_mag_std   537 non-null    float64
#  41  la_x_mean    537 non-null    float64
#  42  la_y_mean    537 non-null    float64
#  43  la_z_mean    537 non-null    float64
#  44  la_x_max     537 non-null    float64
#  45  la_y_max     537 non-null    float64
#  46  la_z_max     537 non-null    float64
#  47  la_x_min     537 non-null    float64
#  48  la_y_min     537 non-null    float64
#  49  la_z_min     537 non-null    float64
#  50  la_x_rmse    537 non-null    float64
#  51  la_y_rmse    537 non-null    float64
#  52  la_z_rmse    537 non-null    float64
#  53  la_x_std     537 non-null    float64
#  54  la_y_std     537 non-null    float64
#  55  la_z_std     537 non-null    float64
#  56  la_mag_mean  537 non-null    float64
#  57  la_mag_max   537 non-null    float64
#  58  la_mag_min   537 non-null    float64
#  59  la_mag_rmse  537 non-null    float64
#  60  la_mag_std   537 non-null    float64
#  61  label        537 non-null    int64
# dtypes: float64(60), int64(2)
# memory usage: 264.3 KB
# None

# %%
# Define the output file path
output_file = 'parents_3.csv'

# Save the concatenated DataFrame to a CSV file
parents_data.to_csv(output_file, index=False)

print(f"Concatenated features saved to {output_file}")
# Out:
# Concatenated features saved to parents_3.csv

# %% [markdown]
# Concat the two csv to have the whole data set :

# %%
import pandas as pd

# Load the CSV files
parents_df = pd.read_csv('parents_3.csv')
kids_df = pd.read_csv('kids_3.csv')

# Concatenate the DataFrames
data= pd.concat([parents_df, kids_df], ignore_index=True)

# Shuffle the combined DataFrame
data = data.sample(frac=1, random_state=42)


# Save the shuffled DataFrame to a new CSV file
data.to_csv('data_3.csv', index=False)

# %%
print(data.head(5))
# Out:
#       id  gy_x_mean  gy_y_mean  gy_z_mean  gy_x_max  gy_y_max  gy_z_max  \
# 319   40   0.001830   0.001090  -0.001095  0.665161  1.021057  0.416946
# 956   19  -0.004149   0.002964  -0.012397  0.870743  0.551285  0.375229
# 1094  20   0.069002  -0.206461  -0.346723  1.366318  0.643494  0.407059
# 86    45   0.002946   0.000428   0.000202  0.713074  0.638000  0.266541
# 990   22   0.019549  -0.004408   0.005758  1.593323  1.885162  1.472916
#
#       gy_x_min  gy_y_min  gy_z_min  ...  la_z_rmse  la_x_std  la_y_std  \
# 319  -0.791153 -0.527039 -0.190201  ...   0.165692  0.093031  0.098044
# 956  -0.869904 -0.697311 -0.947021  ...   0.355238  0.246884  0.221454
# 1094 -1.117706 -3.888367 -5.620560  ...   0.496602  0.377996  0.656716
# 86   -0.384033 -0.560074 -0.208130  ...   0.317568  0.120684  0.147029
# 990  -2.631653 -2.599777 -1.240189  ...   0.339852  0.204047  0.167584
#
#       la_z_std  la_mag_mean  la_mag_max  la_mag_min  la_mag_rmse  la_mag_std  \
# 319   0.157816     0.184032    0.827080    0.004637     0.215655    0.112457
# 956   0.347310     0.530118    6.511254    0.110745     0.628895    0.338451
# 1094  0.436862     0.608166    3.784070    0.049939     0.906965    0.674133
# 86    0.240663     0.306963    2.193570    0.040391     0.373566    0.212959
# 990   0.262151     0.337854    3.462111    0.037485     0.434185    0.272789
#
#       label
# 319       0
# 956       1
# 1094      1
# 86        0
# 990       1
#
# [5 rows x 62 columns]
